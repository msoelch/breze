# %% [markdown]
# Stochastic Recurrent Networks for human movement modelling
# ===============================================================================
#
# This notebook presents how to use stochastic recurrent networks (STORNs) for
# modelling robot movement. The method has been proposed in
#
#  * Bayer, Justin, and Christian Osendorfer. "Learning Stochastic Recurrent Networks." arXiv preprint arXiv:1411.7610 (2014). [Link](arxiv.org/abs/1411.7610).
#
# It is best to revisit the paper to get a theoretical understanding of the method,
# but a quick recap follows.
#
# The model
# ---
#
# We are interested in modelling sequences $\{x_{1:T}\}_{i=1}^N$ over a vectorial
# space. To do so, we assume that the data is generated by the following model:
#
# $$h_t = f(h_{t-1}W + x_t V + z_t \hat{V} + b), \\
# x_{t+1} = g(h_t Q + \hat{b}).$$
#
# Here, $z_t \sim \mathcal{N}(0, 1)$ are **stochastic units** which help to model
# the data.
#
# As can be seen, the model is a generalisation of plain RNNs: if we set
# $\hat{V} = \mathbf{0}$, we will recover an Elman network.
# However, adding stochastic units can greatly enhance the predictive capabilities
# of our model.
#
# For one, it lets us model dependencies between the components of each $x_t$.
# Further, it can express more complicated distributions. For example, the output
# of an RNN is just a point. If we do not attach any probabilistic meanings to
# those points, they will form a Dirac distribution. However, if we integrate all
# the $z_t$ out, we can get any (yes, any) distribution--Gaussian, Laplace,
# student's T or even mixtures.
#
#
# The learning algorithm/estimator
# ---
#
# We are using a certain flavor of variational inference, namely *stochastic gradient variational Bayes* (SGVB)
# to find good paramters--that is $\{h_0, V, \hat{V}, Q, b, \hat{b}\}$--for our model.
# SGVB has been described in
#
#  * Kingma, Diederik P., and Max Welling. "Auto-encoding variational bayes." arXiv preprint arXiv:1312.6114 (2013) and
#  * Rezende, Danilo Jimenez, Shakir Mohamed, and Daan Wierstra. "Stochastic backpropagation and approximate inference in deep generative models." arXiv preprint arXiv:1401.4082 (2014).
#
# but the STORN article features a quick recap. We will do a shorter one.
#
# The main idea is to minimize an upper bound on the negative log-likelihood,
# which also makes a variational approximation $q(z|x)$ close to the true posterior
# $p(z|x)$. This is done by making $q$ a parameterised model conditioned on the
# input (which is weird in the first moment); in the original papers, a neural net
# was used for that. Here, we are using (bidirectional) recurrent networks. The
# parameters of that model (the recognition model or inference model) are optimised
# jointly with the generative model above.
#
# Doing so, we get something for free: $q$ can be used for all kinds of approximate
# inference. We can perform an approximate denoising by looking at an observation $x$,
# obtaining the maximum of the approximate posterior $\text{arg max}_{\hat{z}} q(\hat{z}|x)$
# and then reconstruct $\hat{x}$ from that.
#
# We can also do impute missing values by doing so many times (using sampling from $q$
# instead of MAP) and re-feed each $\hat{x}$ into our model. This is equivalent to MCMC
# sampling from the model. If we clamp some components of $x$, we will do proper missing
# value imputation.
#
# Furthermore, there exists an efficient estimator for the NLL that does not rely on
# a costly Markov chain--something which is not available for the RBM family.
#
#
# Outline
# ---
#
# To proceed with the notebook, you will need the saltier-storn branch of Breze, which can be found here:
#
#   * https://github.com/breze-no-salt/breze/tree/saltier-storn
#
# You can install breze with the usual
#
#   ``pip install --user -e .``
#
# You will also need
# [Theano](http://deeplearning.net/software/theano/) and
# [climin](climin.readthedocs.org).

# %%
# Quite a few imports.

import cPickle
import gzip
import itertools
import math
import time
import h5py

import numpy as np
import theano
import theano.tensor as T

from breze.learn.data import interleave, padzeros, split
from breze.learn import base
from breze.learn import sgvb
import breze.learn.display as D
from breze.learn.data import interleave, padzeros, split

from breze.arch.component.varprop import transfer
from breze.arch.util import WarnNaNMode

import climin.initialize
import climin.stops
import climin.mathadapt as ma

import matplotlib.pyplot as plt
from matplotlib import cm

# %matplotlib inline

theano.config.compute_test_value = 'off'

from scipy.io import loadmat
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %% [markdown]
# Data format
# -------------------------------------------------------------------------------
#
# A word on the data format. To make things efficient, we need to put all the
# sequential data in 3D arrays. This is done by padding the shorter sequences
# with zeros. To make sure that those zeros don't interfer with learning, we will
# also use masks (that is binary matrices) with which the component wise loss
# is multiplied--that way, only the real data points will contribute to it.
#
# It will also mean longer processing times as if all sequences were of the same
# length. But it is way faster than working through each one separately.
#
# An array is thus of the form
#
#   ``(T, N, D)``
#
# where ``T`` is the number of time steps, ``N`` is the number of samples and
# ``D`` is the dimensionality of the data.
#
# The training and validation data will also be chunked into smaller sequences,
# e.g. ``100``. This is not done for the testing data. I personally do not
# believe that it affects performance much.
#
# Naming convention for data
# ---
#
# Throughout Breze, ``X`` is the training data, ``VX`` is the validation data
# and ``TX`` is the testing data. ``M``, ``VM`` and ``TM`` are the corresponding
# masks.
#
# Often, we will not chunk the testing data. In that case, the testing data is
# contained in a list called ``txs``, which contains many sequences of differing
# length of the shape ``(T, D)``. In this case, we only have a single testing
# sequence, which is why it is called ``tx``.

# %%
def load_data(datafile):
    with h5py.File(datafile) as fp:
        dev_seqs = [np.array(fp['dev'][i]) for  i in fp['dev']]
        txs = [np.array(fp['test'][i]) for  i in fp['test']]
        tzs = np.array(fp['test_anomaly_label'])

    x = dev_seqs[:80]
    m = np.concatenate(x).mean(axis=0)
    s = np.concatenate(x).std(axis=0)
    
    x = [(xx-m)/s for xx in x]
    vx = [(vxx-m)/s for vxx in dev_seqs[80:]]
    txs = [(tx-m)/s for tx in txs]
    
        
    X, M = tuple(interleave(l) for l in padzeros(x, front=False, return_mask=True))
    VX, VM = tuple(interleave(l) for l in padzeros(vx, front=False, return_mask=True))
    TX, TM = tuple(interleave(l) for l in padzeros(txs, front=False, return_mask=True))
    M, VM, TM = M[:,:,:1], VM[:,:,:1], TM[:,:,:1]
 
    X, M, VX, VM, tzs = [base.cast_array_to_local_type(i) for i in (X, M, VX, VM, tzs)]
    txs = [base.cast_array_to_local_type(i) for i in txs]
    
    
    print 'training shape', X.shape, M.shape
    print 'validation shape', VX.shape, VM.shape
    print 'test shape', TX.shape, TM.shape, tzs.shape
    
    return X, M, VX, VM, txs, tzs

X, M, VX, VM, txs, tzs = load_data('P:/Datasets/BaxterCollision/data/bluebear/bluebear.h5')
# Out:
# training shape (336L, 80L, 7L) (336L, 80L, 1L)
# validation shape (312L, 20L, 7L) (312L, 20L, 1L)
# test shape (339L, 40L, 7L) (339L, 40L, 1L) (40L,)

# %% [markdown]
# Model initialisation
# --------------------------------------------------------------------------------
#
# Here we initialise the model. We will comment the most important parameters in the
# cell. The hyper parameters were obtained using Bayesian optimisation via whetlab.

# %%
# Adadelta with Nesterov momentum--powerful optimiser for FD-RNNs.
optimizer = 'adadelta', {'step_rate': 1, 
                        'momentum': 0.99, 
                        'decay': 0.78, 
                        'offset': 0.00005, 
                        'step_adapt': False, 'step_rate_min': 1e-8, 'step_rate_max': 1}
# Batch sizes speed up learning for RNNs as well.
batch_size = 5
print type(batch_size)
#  Amount of hidden layers of the recognition and generating model.
n_gen_layers = 3
n_recog_layers = 3

n_hiddens_recog = [50] * n_recog_layers
transfers_recog = ['tanh'] * n_recog_layers
n_hiddens_gen = [50] * n_gen_layers
transfers_gen = ['tanh'] * n_gen_layers
n_latents = 16

# Standard deviation for a Normal from which all parameters are drawn.
par_std = 0.5

# The input-to-hidden weights are drawn from this instead.
in_to_hidden_par_std = 0.000001

# After initialisation, the spectral radius of the recurrent matrices is set to this value.
spectral_radius = 4.65

# The recurrent weight matrices are restricted to only have 50 non-zero elements per row.
sparsify_rec = 50

# Similar for the input matrix.
sparsify_in = 2

# Fast dropout rates for the *generating* model.
p_dropout_inpt = .5
p_dropout_hiddens = .5
p_dropout_hidden_to_out = .12
p_dropout_shortcut = .35

reload(sgvb)

# The assumptions we make. First, we assume that the noise level 
# of the visibles is constant and somewhere around .1 everywhere.
# We assume the latent variables to follow a white Gaussian.
class Assumptions(sgvb.ConstantVarVisibleGaussAssumption, sgvb.DiagGaussLatentAssumption):
    out_std = theano.shared(np.array(.1).astype(theano.config.floatX))

assumptions = Assumptions()

# We can use a bidirectional or unidirectional recognition model. 
# Not possible for the generating model.
#m = sgvb.StochasticRnn(
m = sgvb.BidirectStochasticRnn(
    X.shape[2],
    n_hiddens_recog, n_latents, n_hiddens_gen, transfers_recog, transfers_gen, 
    use_imp_weight=True,
    assumptions=assumptions,
    batch_size=batch_size,
    optimizer=optimizer,
    p_dropout_inpt=p_dropout_inpt,
    p_dropout_hiddens=p_dropout_hiddens,
    p_dropout_hidden_to_out=p_dropout_hidden_to_out,
    p_dropout_shortcut=p_dropout_shortcut)

infos = []
m.exprs['true_loss'] = m.exprs['loss']

m.gradient_clip_threshold = None
# Out:
# <type 'int'>

# %%
m.initialize(
    par_std=par_std, 
    par_std_in=in_to_hidden_par_std, 
    sparsify_affine=sparsify_in, 
    sparsify_rec=sparsify_rec, 
    spectral_radius=None)

# %% [markdown]
# Training
# ===

# %%
infos = []

# %%
m.optimizer = 'adadelta', {'step_rate': 1, 
                        'momentum': 0.99, 
                        'decay': 0.78, 
                        'offset': 0.00005}, 
                        #'step_adapt': False, 'step_rate_min': 1e-8}#, 'step_rate_max': 1}

# %%
import gnumpy
gnumpy.status()
theano.sandbox.cuda.cuda_ndarray.cuda_ndarray.theano_allocated()
# theano.printing.pydotprint(m.loss, outfile='Z:/Desktop/test.png',var_with_name_simple=True)
# Out:
# gnumpy is planning to run on a GPU, but hasn't yet chosen & initialized a board.
# 0 bytes of gpu memory are in use, of which at least 0 bytes can be freed immediately by gnumpy.free_reuse_cache().
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-e53794de7007> in <module>()
#       1 import gnumpy
#       2 gnumpy.status()
# ----> 3 theano.sandbox.cuda.cuda_ndarray.cuda_ndarray.theano_allocated()
#       4 # theano.printing.pydotprint(m.loss, outfile='Z:/Desktop/test.png',var_with_name_simple=True)
#
# AttributeError: 'module' object has no attribute 'theano_allocated'

# %%
def sof(infos):
    size_of_infos = 0
    for _, value in infos[0].iteritems():
        if isinstance(value,(int,float)):
            size_of_infos += 4
        else:
            size_of_infos += 4* value.size

    return size_of_infos

# %%
#m.mode = 'FAST_COMPILE'
#m.optimizer = 'None'

#import gc

max_passes = 100000
max_minutes = 6000
batches_per_pass = int(math.ceil(float(X.shape[1]) / m.batch_size)) if m.batch_size is not None else 1
pause = climin.stops.ModuloNIterations(batches_per_pass * 1)
#pause = climin.stops.ModuloNIterations(1)

stop = climin.stops.Any([
    climin.stops.TimeElapsed(max_minutes * 60),
    #climin.stops.Patience('val_loss', 1000, grow_factor=1.1, threshold=0.0001),
    #climin.stops.not_better_than_after(30, 100),
])
    
start = time.time()
# Set up a nice printout.
header = '#', 'seconds', 'loss', 'val loss', 'test loss'
print '\t'.join(header)

for i, info in enumerate(m.powerfit((X, M), (VX, VM), stop, pause, True)):
    #print theano.sandbox.cuda.cuda_ndarray.cuda_ndarray.theano_allocated()
    #gc.collect(); gc.collect(); gc.collect()
    #gnumpy.status()
    #theano.sandbox.cuda.theano_allocated()
    info['loss'] = float(info['loss'])
    info['val_loss'] = float(info['val_loss'])
    #info['test_loss'] = float(ma.scalar(test_score()))
    
    info.update({
        'time': time.time() - start,
    })
    template = '\t'.join(
        ['%(n_iter)i', '%(time)g', '%(loss)g', '%(val_loss)g'])
    row = template % info
    print row
    
    if theano.config.gpu == 'gpu':
        filtered_info = dict(
            (k, v) for k, v in info.items()
            if (not isinstance(v, (np.ndarray, gnumpy.garray)) or v.size <= 1) and k not in ('args', 'kwargs'))
    else:
        filtered_info = dict(
            (k, v) for k, v in info.items()
            if (not isinstance(v, (np.ndarray, )) or v.size <= 1) and k not in ('args', 'kwargs'))

    for key in filtered_info:
        if isinstance(filtered_info[key], np.float32):
            filtered_info[key] = float(filtered_info[key])
    filtered_info['max_grad'] = np.sqrt((info['gradient'] ** 2).sum())
    infos.append(filtered_info)
# Out:
# z:\anomalydetection\theano_surbarn\theano\theano\scan_module\scan_perform_ext.py:134: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility
#   from scan_perform.scan_perform import *
# z:\anomalydetection\climin\climin\util.py:150: UserWarning: Argument named f is not expected by <class 'climin.adadelta.Adadelta'>
#   % (i, klass))
# #	seconds	loss	val loss	test loss
# 16	210.638	13.9953	14.1298
# 32	240.153	1.2601	1.50019
# 48	269.508	-0.739516	-0.714605
# 64	298.93	-0.964997	-0.953827
# 80	327.943	-1.24794	-1.28872
# 96	357.584	-1.2793	-1.31884
# 112	387.081	-1.3003	-1.34283
# 128	416.69	-1.3115	-1.35497
# 144	446.469	-1.32071	-1.36556
# 160	475.999	-1.32711	-1.37308
# 176	505.438	-1.33162	-1.37855
# 192	536.091	-1.33537	-1.38268
# 208	565.919	-1.33831	-1.38574
# 224	595.697	-1.3397	-1.38758
# 240	625.13	-1.34212	-1.39012
# 256	654.944	-1.34392	-1.39177
# 272	684.679	-1.34441	-1.39243
# 288	714.632	-1.34571	-1.39408
# 304	744.429	-1.34648	-1.3946
# 320	773.826	-1.34774	-1.39614
# 336	803.355	-1.34784	-1.39599
# 352	833.058	-1.34828	-1.39655
# 368	862.427	-1.34922	-1.39733
# 384	892.073	-1.34956	-1.39795
# 400	921.862	-1.34975	-1.3979
# 416	951.855	-1.35015	-1.3985
# 432	982.266	-1.3509	-1.39935
# 448	1012.99	-1.3512	-1.39964
# 464	1043.46	-1.35106	-1.39951
# 480	1073.53	-1.35119	-1.39969
# 496	1103.75	-1.35148	-1.39994
# 512	1133.94	-1.35204	-1.40069
# 528	1163.94	-1.35197	-1.40052
# 544	1194.04	-1.35226	-1.40091
# 560	1224.26	-1.35209	-1.40067
# 576	1254.04	-1.35244	-1.4011
# 592	1283.56	-1.35263	-1.40122
# 608	1313.79	-1.35272	-1.40143
# 624	1344.07	-1.35267	-1.40123
# 640	1373.36	-1.35297	-1.40171
# 656	1402.23	-1.35296	-1.40165
# 672	1431.68	-1.35317	-1.40185
# 688	1460.79	-1.35344	-1.40231
# 704	1490.08	-1.35308	-1.40175
# 720	1519.65	-1.35331	-1.40202
# 736	1549.15	-1.35351	-1.40226
# 752	1579.61	-1.35378	-1.40251
# 768	1610.18	-1.35353	-1.40227
# 784	1640.42	-1.35365	-1.40244
# 800	1670.4	-1.35367	-1.40245
# 816	1700.07	-1.35371	-1.40251
# 832	1729.68	-1.35391	-1.40271
# 848	1759.55	-1.35373	-1.40257
# 864	1789.72	-1.35419	-1.40295
# 880	1819.66	-1.3538	-1.4026
# 896	1849.56	-1.35405	-1.40294
# 912	1879.55	-1.35382	-1.40263
# 928	1909.27	-1.35409	-1.40289
# 944	1939.46	-1.35407	-1.40288
# 960	1969.49	-1.35402	-1.40285
# 976	1999.16	-1.35391	-1.4028
# 992	2028.73	-1.35424	-1.40307
# 1008	2058.34	-1.35406	-1.40278
# 1024	2088.01	-1.35409	-1.40293
# 1040	2118.05	-1.35427	-1.40314
# 1056	2148.38	-1.35441	-1.40323
# 1072	2178.33	-1.35458	-1.40353
# 1088	2208.28	-1.35455	-1.40349
# 1104	2238.69	-1.35452	-1.40347
# 1120	2268.58	-1.35418	-1.40302
# 1136	2298.68	-1.35435	-1.40315
# 1152	2328.3	-1.35422	-1.40313
# 1168	2358.08	-1.35451	-1.40351
# 1184	2388.21	-1.35444	-1.40328
# 1200	2418.09	-1.35435	-1.40323
# 1216	2448.18	-1.35462	-1.40358
# 1232	2478.08	-1.35456	-1.40346
# 1248	2507.31	-1.35433	-1.40318
# 1264	2537.24	-1.3544	-1.40336
# 1280	2567.81	-1.35462	-1.40353
# 1296	2597.55	-1.35476	-1.40374
# 1312	2626.94	-1.35453	-1.40344
# 1328	2656.6	-1.35457	-1.40343
# 1344	2685.87	-1.35458	-1.40347
# 1360	2716.76	-1.35461	-1.40363
# 1376	2746.75	-1.35471	-1.40364
# 1392	2777.71	-1.35474	-1.40379
# 1408	2806.99	-1.35478	-1.40389
# 1424	2837.27	-1.35427	-1.40326
# 1440	2867.67	-1.3547	-1.40371
# 1456	2897.91	-1.35478	-1.40375
# 1472	2927.9	-1.35462	-1.40364
# 1488	2957.26	-1.3549	-1.40388
# 1504	2987.07	-1.35468	-1.40365
# 1520	3017	-1.35479	-1.40378
# 1536	3047.03	-1.35457	-1.40356
# 1552	3076.85	-1.35498	-1.40401
# 1568	3107.72	-1.35475	-1.40379
# 1584	3137.96	-1.35484	-1.40391
# 1600	3168.84	-1.35505	-1.40401
# 1616	3199.47	-1.3548	-1.40381
# 1632	3229.78	-1.35494	-1.40398
# 1648	3259.85	-1.35506	-1.40415
# 1664	3290.02	-1.35526	-1.40436
# 1680	3320.01	-1.35498	-1.40411
# 1696	3349.69	-1.35484	-1.40383
# 1712	3379.39	-1.35514	-1.40422
# 1728	3408.95	-1.35512	-1.40423
# 1744	3438.79	-1.35489	-1.40402
# 1760	3469.09	-1.35505	-1.40419
# 1776	3498.99	-1.35503	-1.40415
# 1792	3528.96	-1.3551	-1.40418
# 1808	3559.14	-1.35496	-1.40406
# 1824	3589.17	-1.35514	-1.40424
# 1840	3619.06	-1.35522	-1.40429
# 1856	3648.72	-1.35485	-1.404
# 1872	3678.38	-1.35483	-1.40385
# 1888	3707.6	-1.35527	-1.4044
# 1904	3736.73	-1.35517	-1.40423
# 1920	3766.07	-1.35533	-1.40443
# 1936	3795.37	-1.35505	-1.40421
# 1952	3824.68	-1.35494	-1.40408
# 1968	3853.85	-1.35507	-1.40417
# 1984	3883.1	-1.35536	-1.40452
# 2000	3913.88	-1.35509	-1.40422
# 2016	3943.43	-1.35522	-1.40438
# 2032	3972.89	-1.35533	-1.40447
# 2048	4002.19	-1.35524	-1.40446
# 2064	4032.23	-1.35503	-1.40426
# 2080	4062.56	-1.35523	-1.40441
# 2096	4091.76	-1.35508	-1.40426
# 2112	4121.09	-1.3553	-1.40441
# 2128	4150.09	-1.35535	-1.40447
# 2144	4179.1	-1.35539	-1.40457
# 2160	4208.43	-1.35537	-1.40449
# 2176	4237.44	-1.35541	-1.40461
# 2192	4266.57	-1.35522	-1.40443
# 2208	4295.51	-1.35529	-1.40439
# 2224	4324.66	-1.35517	-1.40426
# 2240	4356.42	-1.35533	-1.40453
# 2256	4387.41	-1.35542	-1.40459
# 2272	4418.5	-1.35561	-1.40478
# 2288	4449.27	-1.35528	-1.4045
# 2304	4479.55	-1.35516	-1.40438
# 2320	4510.38	-1.35539	-1.40454
# 2336	4541.02	-1.35565	-1.40493
# 2352	4572.57	-1.35551	-1.40472
# 2368	4604.13	-1.35568	-1.405
# 2384	4634.08	-1.35547	-1.40473
# 2400	4663.61	-1.35573	-1.40494
# 2416	4693.87	-1.35571	-1.40494
# 2432	4722.59	-1.35555	-1.40476
# 2448	4751.61	-1.35553	-1.4048
# 2464	4780.2	-1.35568	-1.40487
# 2480	4809.19	-1.35582	-1.40503
# 2496	4837.97	-1.35558	-1.40481
# 2512	4866.8	-1.35569	-1.40492
# 2528	4895.44	-1.35553	-1.4048
# 2544	4924.01	-1.35534	-1.40461
# 2560	4952.76	-1.35578	-1.40505
# 2576	4981.56	-1.3553	-1.40459
# 2592	5010.39	-1.3555	-1.40469
# 2608	5039.29	-1.35551	-1.40482
# 2624	5068.15	-1.35573	-1.40498
# 2640	5096.88	-1.3555	-1.40477
# 2656	5125.78	-1.35546	-1.40472
# 2672	5154.91	-1.35579	-1.40506
# 2688	5183.93	-1.35574	-1.40511
# 2704	5212.77	-1.35536	-1.40471
# 2720	5241.53	-1.3555	-1.40481
# 2736	5270.36	-1.35552	-1.40479
# 2752	5299.16	-1.35512	-1.40441
# 2768	5328.04	-1.35553	-1.40473
# 2784	5357.13	-1.3553	-1.40458
# 2800	5386.01	-1.35579	-1.40506
# 2816	5414.8	-1.35583	-1.40522
# 2832	5443.5	-1.35552	-1.40482
# 2848	5472.3	-1.35539	-1.40471
# 2864	5500.97	-1.35564	-1.40496
# 2880	5529.81	-1.35555	-1.40484
# 2896	5558.62	-1.35569	-1.40497
# 2912	5587.41	-1.35568	-1.40491
# 2928	5616.1	-1.3559	-1.40527
# 2944	5644.65	-1.35569	-1.40499
# 2960	5673.87	-1.35566	-1.40494
# 2976	5702.68	-1.35581	-1.40507
# 2992	5731.56	-1.35579	-1.40508
# 3008	5760.33	-1.35573	-1.40509
# 3024	5789.24	-1.35567	-1.40493
# 3040	5817.98	-1.3558	-1.40516
# 3056	5846.87	-1.35582	-1.40513
# 3072	5875.99	-1.35569	-1.40503
# 3088	5905.02	-1.35582	-1.40512
# 3104	5933.86	-1.35567	-1.40503
# 3120	5962.77	-1.35551	-1.40481
# 3136	5991.58	-1.35601	-1.40539
# 3152	6020.39	-1.35592	-1.40527
# 3168	6049.16	-1.3558	-1.40512
# 3184	6077.93	-1.35573	-1.40509
# 3200	6106.8	-1.35586	-1.40522
# 3216	6137.24	-1.35555	-1.40503
# 3232	6167.82	-1.35597	-1.40533
# 3248	6198.55	-1.35593	-1.40537
# 3264	6229.45	-1.35582	-1.40516
# 3280	6258.59	-1.35586	-1.40535
# 3296	6287.13	-1.3558	-1.40519
# 3312	6315.78	-1.35576	-1.40499
# 3328	6343.99	-1.35578	-1.40511
# 3344	6373.03	-1.35571	-1.40506
# 3360	6401.9	-1.35577	-1.40512
# 3376	6430.53	-1.35578	-1.40518
# 3392	6459.04	-1.35585	-1.40522
# 3408	6487.6	-1.35587	-1.40524
# 3424	6516.17	-1.3561	-1.40557
# 3440	6544.96	-1.35574	-1.40507
# 3456	6573.53	-1.35581	-1.4052
# 3472	6602.23	-1.35594	-1.40528
# 3488	6631.21	-1.35602	-1.40539
# 3504	6661.33	-1.356	-1.40543
# 3520	6690.14	-1.35598	-1.4054
# 3536	6719.05	-1.35569	-1.40503
# 3552	6747.91	-1.35595	-1.4053
# 3568	6776.91	-1.35596	-1.40532
# 3584	6805.74	-1.35615	-1.40562
# 3600	6834.66	-1.35576	-1.40517
# 3616	6863.65	-1.35618	-1.40565
# 3632	6892.39	-1.35605	-1.40546
# 3648	6921.23	-1.35594	-1.40541
# 3664	6950.07	-1.356	-1.40533
# 3680	6978.83	-1.3559	-1.4053
# 3696	7007.52	-1.35597	-1.40532
# 3712	7036.28	-1.35606	-1.40544
# 3728	7065.33	-1.35561	-1.40501
# 3744	7094.2	-1.35628	-1.40567
# 3760	7122.86	-1.3559	-1.40536
# 3776	7151.91	-1.35581	-1.40524
# 3792	7180.74	-1.35607	-1.40541
# 3808	7209.71	-1.35598	-1.40536
# 3824	7238.74	-1.35611	-1.4055
# 3840	7267.58	-1.35596	-1.40535
# 3856	7296.53	-1.35609	-1.40556
# 3872	7325.37	-1.35611	-1.40559
# 3888	7354.09	-1.35608	-1.40554
# 3904	7382.89	-1.35614	-1.40553
# 3920	7412.02	-1.35596	-1.40539
# 3936	7441.29	-1.35614	-1.40564
# 3952	7470.05	-1.35601	-1.40541
# 3968	7498.62	-1.35585	-1.40535
# 3984	7527.63	-1.35597	-1.40548
# 4000	7556.65	-1.35628	-1.40573
# 4016	7585.64	-1.35592	-1.40532
# 4032	7614.45	-1.35633	-1.4058
# 4048	7642.79	-1.35614	-1.4056
# 4064	7671.53	-1.35616	-1.4056
# 4080	7700.35	-1.35617	-1.40566
# 4096	7728.98	-1.35599	-1.40533
# 4112	7757.92	-1.35602	-1.40542
# 4128	7786.94	-1.35612	-1.40555
# 4144	7816.32	-1.35609	-1.40544
# 4160	7845.18	-1.35635	-1.40576
# 4176	7874.17	-1.35632	-1.40576
# 4192	7903.99	-1.35622	-1.40569
# 4208	7933.81	-1.3561	-1.40555
# 4224	7963.53	-1.35577	-1.40525
# 4240	7992.51	-1.35624	-1.40575
# 4256	8021.86	-1.35603	-1.40555
# 4272	8050.73	-1.35626	-1.40563
# 4288	8079.8	-1.35632	-1.40581
# 4304	8109.22	-1.35601	-1.40547
# 4320	8138.63	-1.356	-1.40552
# 4336	8167.84	-1.3561	-1.40553
# 4352	8196.98	-1.35614	-1.40557
# 4368	8225.93	-1.356	-1.40543
# 4384	8255.05	-1.35619	-1.40561
# 4400	8284.08	-1.35617	-1.40555
# 4416	8313.05	-1.35608	-1.40548
# 4432	8342.21	-1.35611	-1.40558
# 4448	8371.19	-1.3562	-1.40563
# 4464	8400.06	-1.35612	-1.40561
# 4480	8428.9	-1.35609	-1.40552
# 4496	8457.84	-1.35636	-1.40587
# 4512	8486.87	-1.35616	-1.40559
# 4528	8515.62	-1.35626	-1.40578
# 4544	8544.52	-1.35632	-1.40581
# 4560	8573.18	-1.35618	-1.40564
# 4576	8602.05	-1.35625	-1.40569
# 4592	8632.54	-1.35614	-1.40556
# 4608	8662.05	-1.3562	-1.40569
# 4624	8694.09	-1.3564	-1.40584
# 4640	8727.88	-1.35599	-1.40549
# 4656	8757.79	-1.35622	-1.40573
# 4672	8787.81	-1.35598	-1.40547
# 4688	8817.77	-1.35594	-1.40544
# 4704	8848.07	-1.35614	-1.40559
# 4720	8878.26	-1.35638	-1.40584
# 4736	8908.66	-1.35589	-1.40531
# 4752	8938.32	-1.35634	-1.40584
# 4768	8968.26	-1.35627	-1.40578
# 4784	8998.79	-1.35603	-1.40554
# 4800	9028.51	-1.3562	-1.40567
# 4816	9057.56	-1.35602	-1.40548
# 4832	9086.81	-1.35624	-1.40576
# 4848	9116.08	-1.35626	-1.40572
# 4864	9145.3	-1.35592	-1.40541
# 4880	9175.43	-1.35617	-1.4056
# 4896	9205.13	-1.35644	-1.40595
# 4912	9234.84	-1.35616	-1.4057
# 4928	9264.31	-1.35621	-1.4057
# 4944	9295.51	-1.35622	-1.40567
# 4960	9325.48	-1.35613	-1.40561
# 4976	9355.27	-1.35638	-1.40596
# 4992	9385.48	-1.35612	-1.40561
# 5008	9415.11	-1.35598	-1.40541
# 5024	9444.34	-1.35613	-1.40559
# 5040	9474.44	-1.35624	-1.40576
# 5056	9504.18	-1.3563	-1.40579
# 5072	9534.12	-1.35638	-1.40583
# 5088	9563.97	-1.35616	-1.40564
# 5104	9594.43	-1.35647	-1.40605

# %%
from theano.compile.profiling import _atexit_print_fn
_atexit_print_fn()
# Out:
# Function profiling
# ==================
#   Message: z:\anomalydetection\breze\breze\arch\util.py:571
#   Time in 0 calls to Function.__call__: 0.000000e+00s
#   Total compile time: 9.923000e+00s
#     Number of Apply nodes: 344
#     Theano Optimizer time: 5.903000e+00s
#        Theano validate time: 6.850007e-01s
#     Theano Linker time (includes C, CUDA code generation/compiling): 3.895000e+00s
#        Import time 3.239985e-01s
#
# Time in all call to theano.grad() 1.491400e+01s
# Time in all call to theano.grad() 1.491400e+01s
# Time in all call to theano.grad() 1.491400e+01s
# Time in all call to theano.grad() 1.491400e+01s
# Function profiling
# ==================
#   Message: z:\anomalydetection\breze\breze\arch\util.py:571
#   Time in 32 calls to Function.__call__: 9.350420e+02s
#   Time in Function.fn.__call__: 9.350410e+02s (100.000%)
#   Time in thunks: 9.340320e+02s (99.892%)
#   Total compile time: 7.629700e+01s
#     Number of Apply nodes: 970
#     Theano Optimizer time: 4.029900e+01s
#        Theano validate time: 9.530008e-01s
#     Theano Linker time (includes C, CUDA code generation/compiling): 3.583200e+01s
#        Import time 1.171000e+00s
#
# Time in all call to theano.grad() 1.491400e+01s
# Class
# ---
# <% time> <sum %> <apply time> <time per call> <type> <#call> <#apply> <Class name>
#   99.7%    99.7%     931.527s       4.85e+00s     Py     192       6   theano.scan_module.scan_op.Scan
#    0.1%    99.8%       0.544s       3.95e-04s     C     1376      43   theano.sandbox.cuda.basic_ops.GpuAlloc
#    0.1%    99.8%       0.509s       3.18e-04s     C     1600      50   theano.sandbox.cuda.basic_ops.GpuIncSubtensor
#    0.0%    99.9%       0.342s       1.60e-04s     C     2144      67   theano.sandbox.cuda.basic_ops.GpuElemwise
#    0.0%    99.9%       0.311s       6.94e-04s     C      448      14   theano.sandbox.cuda.blas.GpuDot22
#    0.0%    99.9%       0.190s       7.42e-04s     C      256       8   theano.sandbox.cuda.blas.GpuDot22Scalar
#    0.0%   100.0%       0.160s       3.33e-04s     C      480      15   theano.sandbox.cuda.basic_ops.GpuCAReduce
#    0.0%   100.0%       0.095s       4.95e-04s     C      192       6   theano.compile.ops.DeepCopyOp
#    0.0%   100.0%       0.067s       6.82e-06s     C     9824     307   theano.tensor.elemwise.Elemwise
#    0.0%   100.0%       0.061s       6.35e-04s     C       96       3   theano.sandbox.cuda.blas.GpuGemm
#    0.0%   100.0%       0.052s       4.06e-04s     C      128       4   theano.sandbox.cuda.basic_ops.GpuJoin
#    0.0%   100.0%       0.042s       1.64e-05s     Py    2560      80   theano.sandbox.cuda.basic_ops.GpuReshape
#    0.0%   100.0%       0.023s       2.40e-04s     C       96       3   theano.sandbox.cuda.basic_ops.HostFromGpu
#    0.0%   100.0%       0.021s       1.34e-05s     C     1568      49   theano.compile.ops.Shape_i
#    0.0%   100.0%       0.019s       5.94e-04s     Py      32       1   theano.tensor.raw_random.RandomFunction
#    0.0%   100.0%       0.019s       1.98e-04s     Py      96       3   theano.sandbox.cuda.basic_ops.GpuSplit
#    0.0%   100.0%       0.015s       9.57e-06s     C     1568      49   theano.tensor.opt.MakeVector
#    0.0%   100.0%       0.013s       8.64e-06s     C     1504      47   theano.tensor.basic.ScalarFromTensor
#    0.0%   100.0%       0.008s       2.55e-06s     C     3136      98   theano.sandbox.cuda.basic_ops.GpuSubtensor
#    0.0%   100.0%       0.006s       2.84e-06s     C     2112      66   theano.sandbox.cuda.basic_ops.GpuDimShuffle
#    ... (remaining 5 Classes account for   0.00%(0.01s) of the runtime)
#
# Ops
# ---
# <% time> <sum %> <apply time> <time per call> <type> <#call> <#apply> <Op name>
#   34.7%    34.7%     324.046s       1.01e+01s     Py      32        1   forall_inplace,gpu,grad_of_scan_fn}
#   34.4%    69.1%     321.335s       1.00e+01s     Py      32        1   forall_inplace,gpu,grad_of_scan_fn}
#   22.8%    91.9%     213.327s       6.67e+00s     Py      32        1   forall_inplace,gpu,grad_of_scan_fn}
#    3.0%    94.9%      27.671s       8.65e-01s     Py      32        1   forall_inplace,gpu,scan_fn}
#    2.8%    97.7%      25.871s       8.08e-01s     Py      32        1   forall_inplace,gpu,scan_fn}
#    2.1%    99.7%      19.277s       6.02e-01s     Py      32        1   forall_inplace,gpu,scan_fn}
#    0.1%    99.8%       0.519s       4.63e-04s     C     1120       35   GpuAlloc{memset_0=True}
#    0.0%    99.8%       0.311s       6.94e-04s     C      448       14   GpuDot22
#    0.0%    99.8%       0.190s       7.42e-04s     C      256        8   GpuDot22Scalar
#    0.0%    99.9%       0.158s       8.23e-04s     C      192        6   GpuIncSubtensor{Inc;:int64:}
#    0.0%    99.9%       0.144s       4.09e-04s     C      352       11   GpuIncSubtensor{InplaceInc;int64::}
#    0.0%    99.9%       0.097s       7.58e-04s     C      128        4   GpuCAReduce{add}{1,0}
#    0.0%    99.9%       0.095s       4.95e-04s     C      192        6   DeepCopyOp
#    0.0%    99.9%       0.081s       1.69e-04s     C      480       15   GpuElemwise{mul,no_inplace}
#    0.0%    99.9%       0.079s       1.54e-04s     C      512       16   GpuIncSubtensor{InplaceInc;int64:int64:}
#    0.0%    99.9%       0.066s       3.44e-04s     C      192        6   GpuElemwise{sqr,no_inplace}
#    0.0%    99.9%       0.061s       6.35e-04s     C       96        3   GpuGemm{inplace}
#    0.0%    99.9%       0.059s       2.63e-04s     C      224        7   GpuIncSubtensor{Set;:int64:}
#    0.0%    99.9%       0.054s       3.38e-04s     C      160        5   GpuElemwise{Add}[(0, 0)]
#    0.0%    99.9%       0.052s       4.06e-04s     C      128        4   GpuJoin
#    ... (remaining 137 Ops account for   0.06%(0.54s) of the runtime)
#
# Apply
# ------
# <% time> <sum %> <apply time> <time per call> <#call> <id> <Mflops> <Gflops/s> <Apply name>
#   34.7%    34.7%     324.046s       1.01e+01s     32   883                     forall_inplace,gpu,grad_of_scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{in
#     input 0: dtype=int64, shape=(), strides=c
#     input 1: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 2: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 3: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 4: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 5: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 6: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 7: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 8: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 9: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 10: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 11: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 12: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 13: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 14: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 15: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     input 16: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     input 17: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     input 18: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     input 19: dtype=float32, shape=(337, 5, 50), strides=(-250, 50, 1)
#     input 20: dtype=float32, shape=(337, 5, 50), strides=(-250, 50, 1)
#     input 21: dtype=float32, shape=(337, 37876), strides=(37876, 1)
#     input 22: dtype=int64, shape=(), strides=c
#     input 23: dtype=int64, shape=(), strides=c
#     input 24: dtype=float32, shape=(37876,), strides=c
#     output 0: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     output 1: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     output 2: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     output 3: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     output 4: dtype=float32, shape=(337, 5, 50), strides=(-250, 50, 1)
#     output 5: dtype=float32, shape=(337, 5, 50), strides=(-250, 50, 1)
#     output 6: dtype=float32, shape=(337, 37876), strides=(37876, 1)
#     output 7: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#     output 8: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#   34.4%    69.1%     321.335s       1.00e+01s     32   882                     forall_inplace,gpu,grad_of_scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{in
#     input 0: dtype=int64, shape=(), strides=c
#     input 1: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#     input 2: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#     input 3: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 4: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 5: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 6: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 7: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 8: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 9: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 10: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 11: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 12: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 13: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 14: dtype=float32, shape=(336, 5, 50), strides=(-250, 50, 1)
#     input 15: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     input 16: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     input 17: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     input 18: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     input 19: dtype=float32, shape=(337, 5, 50), strides=(-250, 50, 1)
#     input 20: dtype=float32, shape=(337, 5, 50), strides=c
#     input 21: dtype=float32, shape=(337, 37876), strides=c
#     input 22: dtype=int64, shape=(), strides=c
#     input 23: dtype=int64, shape=(), strides=c
#     input 24: dtype=float32, shape=(37876,), strides=c
#     output 0: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     output 1: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     output 2: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     output 3: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     output 4: dtype=float32, shape=(337, 5, 50), strides=(-250, 50, 1)
#     output 5: dtype=float32, shape=(337, 5, 50), strides=(-250, 50, 1)
#     output 6: dtype=float32, shape=(337, 37876), strides=(37876, 1)
#     output 7: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#     output 8: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#   22.8%    91.9%     213.327s       6.67e+00s     32   792                     forall_inplace,gpu,grad_of_scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{in
#     input 0: dtype=int64, shape=(), strides=c
#     input 1: dtype=float32, shape=(336, 5, 200), strides=c
#     input 2: dtype=float32, shape=(336, 5, 200), strides=c
#     input 3: dtype=float32, shape=(336, 5, 50), strides=c
#     input 4: dtype=float32, shape=(336, 5, 50), strides=c
#     input 5: dtype=float32, shape=(336, 5, 200), strides=c
#     input 6: dtype=float32, shape=(336, 5, 200), strides=c
#     input 7: dtype=float32, shape=(336, 5, 50), strides=c
#     input 8: dtype=float32, shape=(336, 5, 50), strides=c
#     input 9: dtype=float32, shape=(336, 5, 50), strides=c
#     input 10: dtype=float32, shape=(336, 5, 50), strides=c
#     input 11: dtype=float32, shape=(336, 5, 200), strides=c
#     input 12: dtype=float32, shape=(336, 5, 200), strides=c
#     input 13: dtype=float32, shape=(336, 5, 50), strides=c
#     input 14: dtype=float32, shape=(336, 5, 50), strides=c
#     input 15: dtype=float32, shape=(337, 5, 50), strides=c
#     input 16: dtype=float32, shape=(337, 5, 50), strides=c
#     input 17: dtype=float32, shape=(337, 5, 200), strides=c
#     input 18: dtype=float32, shape=(337, 5, 200), strides=c
#     input 19: dtype=float32, shape=(337, 5, 50), strides=c
#     input 20: dtype=float32, shape=(337, 5, 50), strides=c
#     input 21: dtype=float32, shape=(337, 37876), strides=c
#     input 22: dtype=int64, shape=(), strides=c
#     input 23: dtype=int64, shape=(), strides=c
#     input 24: dtype=float32, shape=(37876,), strides=c
#     output 0: dtype=float32, shape=(337, 5, 50), strides=c
#     output 1: dtype=float32, shape=(337, 5, 50), strides=c
#     output 2: dtype=float32, shape=(337, 5, 200), strides=c
#     output 3: dtype=float32, shape=(337, 5, 200), strides=c
#     output 4: dtype=float32, shape=(337, 5, 50), strides=c
#     output 5: dtype=float32, shape=(337, 5, 50), strides=c
#     output 6: dtype=float32, shape=(337, 37876), strides=c
#     output 7: dtype=float32, shape=(336, 5, 200), strides=c
#     output 8: dtype=float32, shape=(336, 5, 200), strides=c
#    3.0%    94.9%      27.671s       8.65e-01s     32   480                     forall_inplace,gpu,scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuAlloc{memset_0=True}.0, GpuIncSubtensor{Set;:int64:}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuIncSubtensor{Set;:int64:}.0, GpuIncSubtensor{InplaceSet;:int64:}.0, parameters)
#     input 0: dtype=int64, shape=(), strides=c
#     input 1: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 2: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 3: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     input 4: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     input 5: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     input 6: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     input 7: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     input 8: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     input 9: dtype=float32, shape=(37876,), strides=c
#     output 0: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     output 1: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     output 2: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     output 3: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     output 4: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     output 5: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#    2.8%    97.7%      25.871s       8.08e-01s     32   301                     forall_inplace,gpu,scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int8}.0, GpuSubtensor{int64:int64:int8}.0, GpuAlloc{memset_0=True}.0, GpuIncSubtensor{Set;:int64:}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuIncSubtensor{Set;:int64:}.0, GpuIncSubtensor{InplaceSet;:int64:}.0, parameters)
#     input 0: dtype=int64, shape=(), strides=c
#     input 1: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#     input 2: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#     input 3: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     input 4: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     input 5: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     input 6: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     input 7: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     input 8: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     input 9: dtype=float32, shape=(37876,), strides=c
#     output 0: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     output 1: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     output 2: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     output 3: dtype=float32, shape=(337, 5, 200), strides=(1000, 200, 1)
#     output 4: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#     output 5: dtype=float32, shape=(337, 5, 50), strides=(250, 50, 1)
#    2.1%    99.7%      19.277s       6.02e-01s     32   733                     forall_inplace,gpu,scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int8}.0, GpuSubtensor{int64:int64:int8}.0, GpuAlloc{memset_0=True}.0, GpuIncSubtensor{Set;:int64:}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuIncSubtensor{Set;:int64:}.0, GpuIncSubtensor{Set;:int64:}.0, parameters)
#     input 0: dtype=int64, shape=(), strides=c
#     input 1: dtype=float32, shape=(336, 5, 200), strides=c
#     input 2: dtype=float32, shape=(336, 5, 200), strides=c
#     input 3: dtype=float32, shape=(337, 5, 50), strides=c
#     input 4: dtype=float32, shape=(337, 5, 50), strides=c
#     input 5: dtype=float32, shape=(337, 5, 200), strides=c
#     input 6: dtype=float32, shape=(337, 5, 200), strides=c
#     input 7: dtype=float32, shape=(337, 5, 50), strides=c
#     input 8: dtype=float32, shape=(337, 5, 50), strides=c
#     input 9: dtype=float32, shape=(37876,), strides=c
#     output 0: dtype=float32, shape=(337, 5, 50), strides=c
#     output 1: dtype=float32, shape=(337, 5, 50), strides=c
#     output 2: dtype=float32, shape=(337, 5, 200), strides=c
#     output 3: dtype=float32, shape=(337, 5, 200), strides=c
#     output 4: dtype=float32, shape=(337, 5, 50), strides=c
#     output 5: dtype=float32, shape=(337, 5, 50), strides=c
#    0.0%    99.7%       0.106s       3.31e-03s     32   622                     GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0)
#     input 0: dtype=float32, shape=(), strides=c
#     input 1: dtype=int64, shape=(), strides=c
#     input 2: dtype=int64, shape=(), strides=c
#     output 0: dtype=float32, shape=(337, 37876), strides=c
#    0.0%    99.8%       0.101s       3.16e-03s     32   219                     GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0)
#     input 0: dtype=float32, shape=(), strides=c
#     input 1: dtype=int64, shape=(), strides=c
#     input 2: dtype=int64, shape=(), strides=c
#     output 0: dtype=float32, shape=(337, 37876), strides=(37876, 1)
#    0.0%    99.8%       0.070s       2.19e-03s     32   335                     GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0)
#     input 0: dtype=float32, shape=(), strides=c
#     input 1: dtype=int64, shape=(), strides=c
#     input 2: dtype=int64, shape=(), strides=c
#     output 0: dtype=float32, shape=(337, 37876), strides=c
#    0.0%    99.8%       0.054s       1.69e-03s     32   573                     GpuDot22(GpuReshape{2}.0, GpuReshape{2}.0)
#     input 0: dtype=float32, shape=(1680, 23), strides=c
#     input 1: dtype=float32, shape=(23, 200), strides=c
#     output 0: dtype=float32, shape=(1680, 200), strides=c
#    0.0%    99.8%       0.051s       1.59e-03s     32   817                     GpuDot22(GpuReshape{2}.0, GpuDimShuffle{1,0}.0)
#     input 0: dtype=float32, shape=(1680, 200), strides=c
#     input 1: dtype=float32, shape=(200, 23), strides=c
#     output 0: dtype=float32, shape=(1680, 23), strides=c
#    0.0%    99.8%       0.048s       1.50e-03s     32   903                     GpuIncSubtensor{Inc;:int64:}(GpuAlloc{memset_0=True}.0, GpuSubtensor{::int64}.0, ScalarFromTensor.0)
#     input 0: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#     input 1: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 2: dtype=int64, shape=8, strides=c
#     output 0: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#    0.0%    99.8%       0.045s       1.41e-03s     32   899                     GpuIncSubtensor{Inc;:int64:}(GpuAlloc{memset_0=True}.0, GpuSubtensor{::int64}.0, ScalarFromTensor.0)
#     input 0: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#     input 1: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 2: dtype=int64, shape=8, strides=c
#     output 0: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#    0.0%    99.8%       0.044s       1.37e-03s     32   576                     GpuDot22(GpuReshape{2}.0, GpuElemwise{sqr,no_inplace}.0)
#     input 0: dtype=float32, shape=(1680, 23), strides=c
#     input 1: dtype=float32, shape=(23, 200), strides=c
#     output 0: dtype=float32, shape=(1680, 200), strides=c
#    0.0%    99.8%       0.038s       1.19e-03s     32   143                     GpuDot22(GpuReshape{2}.0, GpuReshape{2}.0)
#     input 0: dtype=float32, shape=(1680, 7), strides=(7, 1)
#     input 1: dtype=float32, shape=(7, 200), strides=(200, 1)
#     output 0: dtype=float32, shape=(1680, 200), strides=(200, 1)
#    0.0%    99.8%       0.037s       1.16e-03s     32   528                     GpuJoin(TensorConstant{2}, GpuReshape{3}.0, GpuReshape{3}.0)
#     input 0: dtype=int8, shape=(), strides=c
#     input 1: dtype=float32, shape=(336, 5, 16), strides=c
#     input 2: dtype=float32, shape=(336, 5, 16), strides=c
#     output 0: dtype=float32, shape=(336, 5, 32), strides=c
#    0.0%    99.8%       0.034s       1.06e-03s     32   854                     GpuDot22Scalar(GpuReshape{2}.0, GpuDimShuffle{1,0}.0, HostFromGpu.0)
#     input 0: dtype=float32, shape=(1680, 16), strides=c
#     input 1: dtype=float32, shape=(16, 50), strides=c
#     input 2: dtype=float32, shape=(), strides=c
#     output 0: dtype=float32, shape=(1680, 50), strides=c
#    0.0%    99.8%       0.033s       1.03e-03s     32   786                     GpuDot22Scalar(GpuReshape{2}.0, GpuDimShuffle{1,0}.0, TensorConstant{0.879999995232})
#     input 0: dtype=float32, shape=(1680, 7), strides=c
#     input 1: dtype=float32, shape=(7, 50), strides=c
#     input 2: dtype=float32, shape=(), strides=c
#     output 0: dtype=float32, shape=(1680, 50), strides=c
#    0.0%    99.8%       0.033s       1.03e-03s     32   816                     GpuDot22Scalar(GpuDimShuffle{1,0}.0, GpuReshape{2}.0, TensorConstant{2.0})
#     input 0: dtype=float32, shape=(23, 1680), strides=c
#     input 1: dtype=float32, shape=(1680, 200), strides=c
#     input 2: dtype=float32, shape=(), strides=c
#     output 0: dtype=float32, shape=(23, 200), strides=c
#    0.0%    99.8%       0.032s       1.00e-03s     32   826                     GpuGemm{inplace}(GpuElemwise{mul,no_inplace}.0, TensorConstant{1.0}, GpuDimShuffle{1,0}.0, GpuReshape{2}.0, TensorConstant{1.0})
#     input 0: dtype=float32, shape=(23, 200), strides=c
#     input 1: dtype=float32, shape=(), strides=c
#     input 2: dtype=float32, shape=(23, 1680), strides=c
#     input 3: dtype=float32, shape=(1680, 200), strides=c
#     input 4: dtype=float32, shape=(), strides=c
#     output 0: dtype=float32, shape=(23, 200), strides=c
#    ... (remaining 950 Apply instances account for 0.19%(1.78s) of the runtime)
#
# Memory Profile
# (Sparse variables are ignored)
# (For values in brackets, it's for linker = c|py
# ---
#     Max if no gc (allow_gc=False): 210417KB (210417KB)
#     CPU: 122KB (122KB)
#     GPU: 210295KB (210295KB)
# ---
#     Max if linker=cvm(default): 173523KB (192067KB)
#     CPU: 107KB (105KB)
#     GPU: 173416KB (191961KB)
# ---
#     Memory saved if views are used: 67785KB (67785KB)
#     Memory saved if inplace ops are used: 194270KB (194270KB)
#     Memory saved if gc is enabled: 36893KB (18350KB)
# ---
#
#     <Sum apply outputs (bytes)> <Apply outputs shape> <created/inplace/view> <Apply node>
#
#       57788848B  [(337, 5, 50), (337, 5, 50), (337, 5, 200), (337, 5, 200), (337, 5, 50), (337, 5, 50), (337, 37876), (336, 5, 200), (336, 5, 200)] i i i i i i i c c forall_inplace,gpu,grad_of_scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuSubtensor{::int64}.0, GpuSubtensor{::int64}.0, GpuAlloc{memset_0=True}.0, Elemwise{minimum,no_inplace}.0, Elemwise{minimum,no_inplace}.0, parameters)
#       57788848B  [(337, 5, 50), (337, 5, 50), (337, 5, 200), (337, 5, 200), (337, 5, 50), (337, 5, 50), (337, 37876), (336, 5, 200), (336, 5, 200)] i i i i i i i c c forall_inplace,gpu,grad_of_scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuSubtensor{::int64}.0, GpuSubtensor{::int64}.0, GpuAlloc{memset_0=True}.0, Elemwise{minimum,no_inplace}.0, Elemwise{minimum,no_inplace}.0, parameters)
#       57788848B  [(337, 5, 50), (337, 5, 50), (337, 5, 200), (337, 5, 200), (337, 5, 50), (337, 5, 50), (337, 37876), (336, 5, 200), (336, 5, 200)] i i i i i i i c c forall_inplace,gpu,grad_of_scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuSubtensor{::int64}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, Elemwise{minimum,no_inplace}.0, Elemwise{minimum,no_inplace}.0, parameters)
#       51056848B  [(337, 37876)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0)
#       51056848B  [(337, 37876)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0)
#       51056848B  [(337, 37876)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0)
#        4044000B  [(337, 5, 50), (337, 5, 50), (337, 5, 200), (337, 5, 200), (337, 5, 50), (337, 5, 50)] i i i i i i forall_inplace,gpu,scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuAlloc{memset_0=True}.0, GpuIncSubtensor{Set;:int64:}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuIncSubtensor{Set;:int64:}.0, GpuIncSubtensor{InplaceSet;:int64:}.0, parameters)
#        4044000B  [(337, 5, 50), (337, 5, 50), (337, 5, 200), (337, 5, 200), (337, 5, 50), (337, 5, 50)] i i i i i i forall_inplace,gpu,scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int8}.0, GpuSubtensor{int64:int64:int8}.0, GpuAlloc{memset_0=True}.0, GpuIncSubtensor{Set;:int64:}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuIncSubtensor{Set;:int64:}.0, GpuIncSubtensor{InplaceSet;:int64:}.0, parameters)
#        4044000B  [(337, 5, 50), (337, 5, 50), (337, 5, 200), (337, 5, 200), (337, 5, 50), (337, 5, 50)] i i i i i i forall_inplace,gpu,scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int8}.0, GpuSubtensor{int64:int64:int8}.0, GpuAlloc{memset_0=True}.0, GpuIncSubtensor{Set;:int64:}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuIncSubtensor{Set;:int64:}.0, GpuIncSubtensor{Set;:int64:}.0, parameters)
#        1348000B  [(337, 5, 200)] c DeepCopyOp(GpuAlloc{memset_0=True}.0)
#        1348000B  [(337, 5, 200)] c DeepCopyOp(GpuAlloc{memset_0=True}.0)
#        1348000B  [(337, 5, 200)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{1}.0, Shape_i{2}.0)
#        1348000B  [(337, 5, 200)] c DeepCopyOp(GpuAlloc{memset_0=True}.0)
#        1348000B  [(337, 5, 200)] c DeepCopyOp(GpuAlloc{memset_0=True}.0)
#        1348000B  [(337, 5, 200)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{1}.0, TensorConstant{200})
#        1348000B  [(337, 5, 200)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{1}.0, Shape_i{2}.0)
#        1348000B  [(337, 5, 200)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{1}.0, TensorConstant{200})
#        1348000B  [(337, 5, 200)] c DeepCopyOp(GpuAlloc{memset_0=True}.0)
#        1348000B  [(337, 5, 200)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{1}.0, TensorConstant{200})
#        1348000B  [(337, 5, 200)] c DeepCopyOp(GpuAlloc{memset_0=True}.0)
#    ... (remaining 950 Apply account for 130314364B/483811452B ((26.93%)) of the Apply with dense outputs sizes)
#
#     <created/inplace/view> is taken from the Op's declaration.
#     Apply nodes marked 'inplace' or 'view' may actually allocate memory, this is not reported here. If you use DebugMode, warnings will be emitted in those cases.
#
#
# Scan Op profiling ( scan_fn )
# ==================
#   Message: None
#   Time in 32 calls of the op (for a total of 10752 steps) 2.586400e+01s
#
#   Total time spent in calling the VM 2.575400e+01s (99.575%)
#   Total overhead (computing slices..) 1.100001e-01s (0.425%)
#
# Time in all call to theano.grad() 1.491400e+01s
# Class
# ---
# <% time> <sum %> <apply time> <time per call> <type> <#call> <#apply> <Class name>
#   75.3%    75.3%      13.305s       6.19e-05s     C   215040      20   theano.sandbox.cuda.basic_ops.GpuElemwise
#   15.5%    90.7%       2.739s       1.27e-04s     C    21504       2   theano.sandbox.cuda.blas.GpuGemm
#    3.5%    94.3%       0.621s       4.81e-06s     C   129024      12   theano.sandbox.cuda.basic_ops.GpuSubtensor
#    2.3%    96.6%       0.407s       1.89e-05s     Py   21504       2   theano.sandbox.cuda.basic_ops.GpuReshape
#    1.8%    98.4%       0.324s       3.01e-05s     C    10752       1   theano.sandbox.cuda.basic_ops.HostFromGpu
#    0.6%    99.0%       0.110s       5.12e-06s     C    21504       2   theano.sandbox.cuda.basic_ops.GpuDimShuffle
#    0.4%    99.4%       0.075s       3.49e-06s     C    21504       2   theano.tensor.basic.ScalarFromTensor
#    0.4%    99.8%       0.062s       5.77e-06s     C    10752       1   theano.compile.ops.Shape_i
#    0.2%   100.0%       0.038s       3.53e-06s     C    10752       1   theano.tensor.elemwise.Elemwise
#    ... (remaining 0 Classes account for   0.00%(0.00s) of the runtime)
#
# Ops
# ---
# <% time> <sum %> <apply time> <time per call> <type> <#call> <#apply> <Op name>
#   15.5%    15.5%       2.739s       1.27e-04s     C     21504        2   GpuGemm{no_inplace}
#   10.5%    26.0%       1.850s       5.74e-05s     C     32256        3   GpuElemwise{mul,no_inplace}
#    7.4%    33.4%       1.315s       6.12e-05s     C     21504        2   GpuElemwise{Sqr}[(0, 0)]
#    7.1%    40.5%       1.254s       5.83e-05s     C     21504        2   GpuElemwise{Composite{scalar_sigmoid((i0 / sqrt((i1 + (i2 * i3)))))},no_inplace}
#    6.9%    47.4%       1.226s       5.70e-05s     C     21504        2   GpuElemwise{Mul}[(0, 0)]
#    6.7%    54.1%       1.184s       5.51e-05s     C     21504        2   GpuElemwise{add,no_inplace}
#    5.7%    59.8%       1.007s       9.37e-05s     C     10752        1   GpuElemwise{sqr,no_inplace}
#    4.4%    64.2%       0.770s       7.16e-05s     C     10752        1   GpuElemwise{Sub}[(0, 1)]
#    4.3%    68.5%       0.769s       7.15e-05s     C     10752        1   GpuElemwise{Composite{(i0 * scalar_sigmoid(i1))},no_inplace}
#    4.0%    72.5%       0.702s       6.53e-05s     C     10752        1   GpuElemwise{Composite{((((sqr(i0) * i1) + (i2 * sqr(i3))) + (i2 * i1)) + (((sqr(i4) * i5) + ((i6 * i7) * sqr(i8))) + ((i6 * i7) * i5)))},no_inplace}
#    3.9%    76.3%       0.681s       6.33e-05s     C     10752        1   GpuElemwise{Composite{(((sqr(i0) * i1) + (Composite{(scalar_sigmoid(((i0 * (i1 + i2 + i3)) / sqrt((i4 + (i5 * i6))))) - sqr(i7))}(i2, i3, i4, i5, i6, i7, i8, i9) * sqr(i10))) + (Composite{(scalar_sigmoid(((i0 * (i1 + i2 + i3)) / sqrt((i4 + (i5 * i6))))) - sqr(i7))}(i2, i3, i4, i5, i6, i7, i8, i9) * i1))},no_inplace}
#    3.8%    80.1%       0.673s       6.26e-05s     C     10752        1   GpuElemwise{Clip}[(0, 0)]
#    3.7%    83.9%       0.659s       6.13e-05s     C     10752        1   GpuElemwise{Composite{(scalar_sigmoid(((i0 * (i1 + i2)) / sqrt((i3 + (i4 * i5))))) - sqr(i6))},no_inplace}
#    3.4%    87.3%       0.609s       5.66e-05s     C     10752        1   GpuElemwise{clip,no_inplace}
#    3.4%    90.7%       0.606s       5.64e-05s     C     10752        1   GpuElemwise{Composite{(((i0 * i1) + (sqr(i2) * i1)) + (i0 * i3))},no_inplace}
#    1.8%    92.6%       0.324s       3.01e-05s     C     10752        1   HostFromGpu
#    1.2%    93.8%       0.217s       2.02e-05s     Py    10752        1   GpuReshape{1}
#    1.1%    94.9%       0.194s       4.51e-06s     C     43008        4   GpuSubtensor{::, int64::}
#    1.1%    96.0%       0.190s       1.77e-05s     Py    10752        1   GpuReshape{2}
#    0.9%    96.9%       0.162s       3.77e-06s     C     43008        4   GpuSubtensor{::, :int64:}
#    ... (remaining 7 Ops account for   3.11%(0.55s) of the runtime)
#
# Apply
# ------
# <% time> <sum %> <apply time> <time per call> <#call> <id> <Mflops> <Gflops/s> <Apply name>
#    8.0%     8.0%       1.409s       1.31e-04s   10752    18                     GpuGemm{no_inplace}(<CudaNdarrayType(float32, matrix)>, HostFromGpu.0, <CudaNdarrayType(float32, matrix)>, GpuReshape{2}.0, TensorConstant{1.0})
#     input 0: dtype=float32, shape=(5, 200), strides=c
#     input 1: dtype=float32, shape=(), strides=c
#     input 2: dtype=float32, shape=(5, 50), strides=c
#     input 3: dtype=float32, shape=(50, 200), strides=c
#     input 4: dtype=float32, shape=(), strides=c
#     output 0: dtype=float32, shape=(5, 200), strides=c
#    7.5%    15.5%       1.330s       1.24e-04s   10752    23                     GpuGemm{no_inplace}(<CudaNdarrayType(float32, matrix)>, TensorConstant{1.0}, GpuElemwise{Composite{(((i0 * i1) + (sqr(i2) * i1)) + (i0 * i3))},no_inplace}.0, GpuElemwise{sqr,no_inplace}.0, TensorConstant{1.0})
#     input 0: dtype=float32, shape=(5, 200), strides=c
#     input 1: dtype=float32, shape=(), strides=c
#     input 2: dtype=float32, shape=(5, 50), strides=c
#     input 3: dtype=float32, shape=(50, 200), strides=c
#     input 4: dtype=float32, shape=(), strides=c
#     output 0: dtype=float32, shape=(5, 200), strides=c
#    5.7%    21.2%       1.007s       9.37e-05s   10752     7                     GpuElemwise{sqr,no_inplace}(GpuReshape{2}.0)
#     input 0: dtype=float32, shape=(50, 200), strides=c
#     output 0: dtype=float32, shape=(50, 200), strides=c
#    4.4%    25.5%       0.770s       7.16e-05s   10752    12                     GpuElemwise{Sub}[(0, 1)](CudaNdarrayConstant{[[ 0.99000001]]}, GpuElemwise{Composite{(i0 * scalar_sigmoid(i1))},no_inplace}.0)
#     input 0: dtype=float32, shape=(1, 1), strides=c
#     input 1: dtype=float32, shape=(1, 1), strides=c
#     output 0: dtype=float32, shape=(1, 1), strides=c
#    4.3%    29.9%       0.769s       7.15e-05s   10752    10                     GpuElemwise{Composite{(i0 * scalar_sigmoid(i1))},no_inplace}(CudaNdarrayConstant{[[ 0.49000001]]}, GpuDimShuffle{x,0}.0)
#     input 0: dtype=float32, shape=(1, 1), strides=c
#     input 1: dtype=float32, shape=(1, 1), strides=c
#     output 0: dtype=float32, shape=(1, 1), strides=c
#    4.0%    33.9%       0.702s       6.53e-05s   10752    35                     GpuElemwise{Composite{((((sqr(i0) * i1) + (i2 * sqr(i3))) + (i2 * i1)) + (((sqr(i4) * i5) + ((i6 * i7) * sqr(i8))) + ((i6 * i7) * i5)))},no_inplace}(GpuSubtensor{::, :int64:}.0, GpuSubtensor{::, :int64:}.0, GpuSubtensor{::, :int64:}.0, GpuSubtensor{::, :int64:}.0, GpuElemwise{mul,no_inplace}.0, GpuSubtensor{::, int64:int64:}.0, <CudaNdarrayType(float32, matrix)>, GpuElemwise{Sqr}[(0, 0)].0, GpuSubtensor{::, int64:int64:}.0)
#     input 0: dtype=float32, shape=(5, 50), strides=c
#     input 1: dtype=float32, shape=(5, 50), strides=c
#     input 2: dtype=float32, shape=(5, 50), strides=c
#     input 3: dtype=float32, shape=(5, 50), strides=c
#     input 4: dtype=float32, shape=(5, 50), strides=c
#     input 5: dtype=float32, shape=(5, 50), strides=c
#     input 6: dtype=float32, shape=(5, 50), strides=c
#     input 7: dtype=float32, shape=(1, 1), strides=c
#     input 8: dtype=float32, shape=(5, 50), strides=c
#     output 0: dtype=float32, shape=(5, 50), strides=c
#    3.9%    37.7%       0.681s       6.33e-05s   10752    22                     GpuElemwise{Sqr}[(0, 0)](GpuElemwise{Mul}[(0, 0)].0)
#     input 0: dtype=float32, shape=(1, 1), strides=c
#     output 0: dtype=float32, shape=(1, 1), strides=c
#    3.9%    41.6%       0.681s       6.33e-05s   10752    41                     GpuElemwise{Composite{(((sqr(i0) * i1) + (Composite{(scalar_sigmoid(((i0 * (i1 + i2 + i3)) / sqrt((i4 + (i5 * i6))))) - sqr(i7))}(i2, i3, i4, i5, i6, i7, i8, i9) * sqr(i10))) + (Composite{(scalar_sigmoid(((i0 * (i1 + i2 + i3)) / sqrt((i4 + (i5 * i6))))) - sqr(i7))}(i2, i3, i4, i5, i6, i7, i8, i9) * i1))},no_inplace}(GpuElemwise{clip,no_inplace}.0, GpuSubtensor{::, int64::}.0, CudaNdarrayConstant{[[ 1.17157292]]}, CudaNdarrayConst
#     input 0: dtype=float32, shape=(5, 50), strides=c
#     input 1: dtype=float32, shape=(5, 50), strides=c
#     input 2: dtype=float32, shape=(1, 1), strides=c
#     input 3: dtype=float32, shape=(1, 1), strides=c
#     input 4: dtype=float32, shape=(5, 50), strides=c
#     input 5: dtype=float32, shape=(5, 50), strides=c
#     input 6: dtype=float32, shape=(1, 1), strides=c
#     input 7: dtype=float32, shape=(1, 1), strides=c
#     input 8: dtype=float32, shape=(5, 50), strides=c
#     input 9: dtype=float32, shape=(5, 50), strides=c
#     input 10: dtype=float32, shape=(5, 50), strides=c
#     output 0: dtype=float32, shape=(5, 50), strides=c
#    3.8%    45.4%       0.679s       6.32e-05s   10752    26                     GpuElemwise{Composite{scalar_sigmoid((i0 / sqrt((i1 + (i2 * i3)))))},no_inplace}(GpuSubtensor{::, int64::}.0, CudaNdarrayConstant{[[ 1.]]}, CudaNdarrayConstant{[[ 0.39269909]]}, GpuSubtensor{::, int64::}.0)
#     input 0: dtype=float32, shape=(5, 150), strides=c
#     input 1: dtype=float32, shape=(1, 1), strides=c
#     input 2: dtype=float32, shape=(1, 1), strides=c
#     input 3: dtype=float32, shape=(5, 150), strides=c
#     output 0: dtype=float32, shape=(5, 150), strides=c
#    3.8%    49.2%       0.673s       6.26e-05s   10752    28                     GpuElemwise{Clip}[(0, 0)](GpuElemwise{Composite{scalar_sigmoid((i0 / sqrt((i1 + (i2 * i3)))))},no_inplace}.0, CudaNdarrayConstant{[[  1.00000001e-07]]}, CudaNdarrayConstant{[[ 0.99999988]]})
#     input 0: dtype=float32, shape=(5, 150), strides=c
#     input 1: dtype=float32, shape=(1, 1), strides=c
#     input 2: dtype=float32, shape=(1, 1), strides=c
#     output 0: dtype=float32, shape=(5, 150), strides=c
#    3.8%    53.0%       0.668s       6.21e-05s   10752    14                     GpuElemwise{mul,no_inplace}(<CudaNdarrayType(float32, matrix)>, GpuElemwise{Sub}[(0, 1)].0)
#     input 0: dtype=float32, shape=(5, 50), strides=c
#     input 1: dtype=float32, shape=(1, 1), strides=c
#     output 0: dtype=float32, shape=(5, 50), strides=c
#    3.7%    56.7%       0.659s       6.13e-05s   10752    27                     GpuElemwise{Composite{(scalar_sigmoid(((i0 * (i1 + i2)) / sqrt((i3 + (i4 * i5))))) - sqr(i6))},no_inplace}(CudaNdarrayConstant{[[ 1.17157292]]}, CudaNdarrayConstant{[[-0.88137364]]}, GpuSubtensor{::, int64::}.0, CudaNdarrayConstant{[[ 1.]]}, CudaNdarrayConstant{[[ 0.53901213]]}, GpuSubtensor{::, int64::}.0, GpuElemwise{Composite{scalar_sigmoid((i0 / sqrt((i1 + (i2 * i3)))))},no_inplace}.0)
#     input 0: dtype=float32, shape=(1, 1), strides=c
#     input 1: dtype=float32, shape=(1, 1), strides=c
#     input 2: dtype=float32, shape=(5, 150), strides=c
#     input 3: dtype=float32, shape=(1, 1), strides=c
#     input 4: dtype=float32, shape=(1, 1), strides=c
#     input 5: dtype=float32, shape=(5, 150), strides=c
#     input 6: dtype=float32, shape=(5, 150), strides=c
#     output 0: dtype=float32, shape=(5, 150), strides=c
#    3.6%    60.3%       0.634s       5.90e-05s   10752    17                     GpuElemwise{Sqr}[(0, 0)](GpuElemwise{Sub}[(0, 1)].0)
#     input 0: dtype=float32, shape=(1, 1), strides=c
#     output 0: dtype=float32, shape=(1, 1), strides=c
#    3.5%    63.8%       0.621s       5.78e-05s   10752    16                     GpuElemwise{Mul}[(0, 0)](GpuElemwise{add,no_inplace}.0, GpuElemwise{Sub}[(0, 1)].0)
#     input 0: dtype=float32, shape=(1, 1), strides=c
#     input 1: dtype=float32, shape=(1, 1), strides=c
#     output 0: dtype=float32, shape=(1, 1), strides=c
#    3.5%    67.3%       0.612s       5.69e-05s   10752    36                     GpuElemwise{mul,no_inplace}(GpuSubtensor{::, :int64:}.0, GpuSubtensor{::, :int64:}.0)
#     input 0: dtype=float32, shape=(5, 50), strides=c
#     input 1: dtype=float32, shape=(5, 50), strides=c
#     output 0: dtype=float32, shape=(5, 50), strides=c
#    3.4%    70.7%       0.609s       5.66e-05s   10752    40                     GpuElemwise{clip,no_inplace}(GpuElemwise{Composite{scalar_sigmoid((i0 / sqrt((i1 + (i2 * i3)))))},no_inplace}.0, CudaNdarrayConstant{[[  1.00000001e-07]]}, CudaNdarrayConstant{[[ 0.99999988]]})
#     input 0: dtype=float32, shape=(5, 50), strides=c
#     input 1: dtype=float32, shape=(1, 1), strides=c
#     input 2: dtype=float32, shape=(1, 1), strides=c
#     output 0: dtype=float32, shape=(5, 50), strides=c
#    3.4%    74.1%       0.606s       5.64e-05s   10752    19                     GpuElemwise{Composite{(((i0 * i1) + (sqr(i2) * i1)) + (i0 * i3))},no_inplace}(<CudaNdarrayType(float32, matrix)>, GpuElemwise{Mul}[(0, 0)].0, <CudaNdarrayType(float32, matrix)>, GpuElemwise{Sqr}[(0, 0)].0)
#     input 0: dtype=float32, shape=(5, 50), strides=c
#     input 1: dtype=float32, shape=(1, 1), strides=c
#     input 2: dtype=float32, shape=(5, 50), strides=c
#     input 3: dtype=float32, shape=(1, 1), strides=c
#     output 0: dtype=float32, shape=(5, 50), strides=c
#    3.4%    77.6%       0.605s       5.63e-05s   10752    37                     GpuElemwise{Mul}[(0, 0)](GpuElemwise{mul,no_inplace}.0, GpuSubtensor{::, int64:int64:}.0)
#     input 0: dtype=float32, shape=(5, 50), strides=c
#     input 1: dtype=float32, shape=(5, 50), strides=c
#     output 0: dtype=float32, shape=(5, 50), strides=c
#    3.4%    81.0%       0.600s       5.58e-05s   10752    38                     GpuElemwise{add,no_inplace}(GpuElemwise{mul,no_inplace}.0, GpuElemwise{Mul}[(0, 0)].0)
#     input 0: dtype=float32, shape=(5, 50), strides=c
#     input 1: dtype=float32, shape=(5, 50), strides=c
#     output 0: dtype=float32, shape=(5, 50), strides=c
#    3.3%    84.3%       0.584s       5.43e-05s   10752    11                     GpuElemwise{add,no_inplace}(CudaNdarrayConstant{[[ 0.01]]}, GpuElemwise{Composite{(i0 * scalar_sigmoid(i1))},no_inplace}.0)
#     input 0: dtype=float32, shape=(1, 1), strides=c
#     input 1: dtype=float32, shape=(1, 1), strides=c
#     output 0: dtype=float32, shape=(1, 1), strides=c
#    ... (remaining 23 Apply instances account for 15.73%(2.78s) of the runtime)
#
# Memory Profile
# (Sparse variables are ignored)
# (For values in brackets, it's for linker = c|py
# ---
#     Max if no gc (allow_gc=False): 62KB (62KB)
#     CPU: 0KB (0KB)
#     GPU: 62KB (62KB)
# ---
#     Max if linker=cvm(default): 45KB (49KB)
#     CPU: 0KB (0KB)
#     GPU: 45KB (49KB)
# ---
#     Memory saved if views are used: 92KB (92KB)
#     Memory saved if inplace ops are used: 4KB (4KB)
#     Memory saved if gc is enabled: 16KB (12KB)
# ---
#
#     <Sum apply outputs (bytes)> <Apply outputs shape> <created/inplace/view> <Apply node>
#
#          40000B  [(50, 200)] c GpuElemwise{sqr,no_inplace}(GpuReshape{2}.0)
#          40000B  [(50, 200)] v GpuReshape{2}(GpuSubtensor{int64:int64:}.0, TensorConstant{[ 50 200]})
#          40000B  [(10000,)] v GpuSubtensor{int64:int64:}(parameters_copy[cuda], Constant{1702}, Constant{11702})
#           4000B  [(5, 200)] c GpuGemm{no_inplace}(<CudaNdarrayType(float32, matrix)>, TensorConstant{1.0}, GpuElemwise{Composite{(((i0 * i1) + (sqr(i2) * i1)) + (i0 * i3))},no_inplace}.0, GpuElemwise{sqr,no_inplace}.0, TensorConstant{1.0})
#           4000B  [(5, 200)] c GpuGemm{no_inplace}(<CudaNdarrayType(float32, matrix)>, HostFromGpu.0, <CudaNdarrayType(float32, matrix)>, GpuReshape{2}.0, TensorConstant{1.0})
#           3000B  [(5, 150)] c GpuElemwise{Composite{scalar_sigmoid((i0 / sqrt((i1 + (i2 * i3)))))},no_inplace}(GpuSubtensor{::, int64::}.0, CudaNdarrayConstant{[[ 1.]]}, CudaNdarrayConstant{[[ 0.39269909]]}, GpuSubtensor{::, int64::}.0)
#           3000B  [(5, 150)] c GpuElemwise{Composite{(scalar_sigmoid(((i0 * (i1 + i2)) / sqrt((i3 + (i4 * i5))))) - sqr(i6))},no_inplace}(CudaNdarrayConstant{[[ 1.17157292]]}, CudaNdarrayConstant{[[-0.88137364]]}, GpuSubtensor{::, int64::}.0, CudaNdarrayConstant{[[ 1.]]}, CudaNdarrayConstant{[[ 0.53901213]]}, GpuSubtensor{::, int64::}.0, GpuElemwise{Composite{scalar_sigmoid((i0 / sqrt((i1 + (i2 * i3)))))},no_inplace}.0)
#           3000B  [(5, 150)] v GpuSubtensor{::, int64::}(GpuGemm{no_inplace}.0, ScalarFromTensor.0)
#           3000B  [(5, 150)] v GpuSubtensor{::, int64::}(GpuGemm{no_inplace}.0, ScalarFromTensor.0)
#           3000B  [(5, 150)] i GpuElemwise{Clip}[(0, 0)](GpuElemwise{Composite{scalar_sigmoid((i0 / sqrt((i1 + (i2 * i3)))))},no_inplace}.0, CudaNdarrayConstant{[[  1.00000001e-07]]}, CudaNdarrayConstant{[[ 0.99999988]]})
#    ... (remaining 33 Apply account for 18076B/161076B ((11.22%)) of the Apply with dense outputs sizes)
#
#     <created/inplace/view> is taken from the Op's declaration.
#     Apply nodes marked 'inplace' or 'view' may actually allocate memory, this is not reported here. If you use DebugMode, warnings will be emitted in those cases.
#
#
# Scan Op profiling ( scan_fn )
# ==================
#   Message: None
#   Time in 32 calls of the op (for a total of 10752 steps) 2.765300e+01s
#
#   Total time spent in calling the VM 2.744800e+01s (99.259%)
#   Total overhead (computing slices..) 2.050004e-01s (0.741%)
#
# Time in all call to theano.grad() 1.491400e+01s
# Class
# ---
# <% time> <sum %> <apply time> <time per call> <type> <#call> <#apply> <Class name>
#   76.6%    76.6%      14.698s       6.84e-05s     C   215040      20   theano.sandbox.cuda.basic_ops.GpuElemwise
#   15.1%    91.7%       2.905s       1.35e-04s     C    21504       2   theano.sandbox.cuda.blas.GpuGemm
#    3.3%    95.0%       0.634s       4.91e-06s     C   129024      12   theano.sandbox.cuda.basic_ops.GpuSubtensor
#    1.9%    97.0%       0.373s       1.73e-05s     Py   21504       2   theano.sandbox.cuda.basic_ops.GpuReshape
# ...
#     input 9: dtype=float32, shape=(37876,), strides=c
#     output 0: dtype=float32, shape=(337, 5, 50), strides=c
#     output 1: dtype=float32, shape=(337, 5, 50), strides=c
#     output 2: dtype=float32, shape=(337, 5, 200), strides=c
#     output 3: dtype=float32, shape=(337, 5, 200), strides=c
#     output 4: dtype=float32, shape=(337, 5, 50), strides=c
#     output 5: dtype=float32, shape=(337, 5, 50), strides=c
#    0.4%    99.1%       3.500s       8.75e-01s      4   194                     forall_inplace,gpu,scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int8}.0, GpuSubtensor{int64:int64:int8}.0, GpuAlloc{memset_0=True}.0, GpuIncSubtensor{Set;:int64:}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuIncSubtensor{Set;:int64:}.0, GpuIncSubtensor{InplaceSet;:int64:}.0, parameters)
#     input 0: dtype=int64, shape=(), strides=c
#     input 1: dtype=float32, shape=(312, 20, 200), strides=(4000, 200, 1)
#     input 2: dtype=float32, shape=(312, 20, 200), strides=(4000, 200, 1)
#     input 3: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     input 4: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     input 5: dtype=float32, shape=(313, 20, 200), strides=(4000, 200, 1)
#     input 6: dtype=float32, shape=(313, 20, 200), strides=(4000, 200, 1)
#     input 7: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     input 8: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     input 9: dtype=float32, shape=(37876,), strides=c
#     output 0: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     output 1: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     output 2: dtype=float32, shape=(313, 20, 200), strides=(4000, 200, 1)
#     output 3: dtype=float32, shape=(313, 20, 200), strides=(4000, 200, 1)
#     output 4: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     output 5: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#    0.4%    99.4%       3.394s       8.49e-01s      4   193                     forall_inplace,gpu,scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuAlloc{memset_0=True}.0, GpuIncSubtensor{Set;:int64:}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuIncSubtensor{Set;:int64:}.0, GpuIncSubtensor{InplaceSet;:int64:}.0, parameters)
#     input 0: dtype=int64, shape=(), strides=c
#     input 1: dtype=float32, shape=(312, 20, 200), strides=(-4000, 200, 1)
#     input 2: dtype=float32, shape=(312, 20, 200), strides=(-4000, 200, 1)
#     input 3: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     input 4: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     input 5: dtype=float32, shape=(313, 20, 200), strides=(4000, 200, 1)
#     input 6: dtype=float32, shape=(313, 20, 200), strides=(4000, 200, 1)
#     input 7: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     input 8: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     input 9: dtype=float32, shape=(37876,), strides=c
#     output 0: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     output 1: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     output 2: dtype=float32, shape=(313, 20, 200), strides=(4000, 200, 1)
#     output 3: dtype=float32, shape=(313, 20, 200), strides=(4000, 200, 1)
#     output 4: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     output 5: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#    0.3%    99.7%       2.571s       6.43e-01s      4   324                     forall_inplace,gpu,scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int8}.0, GpuSubtensor{int64:int64:int8}.0, GpuAlloc{memset_0=True}.0, GpuIncSubtensor{Set;:int64:}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuIncSubtensor{Set;:int64:}.0, GpuIncSubtensor{InplaceSet;:int64:}.0, parameters)
#     input 0: dtype=int64, shape=(), strides=c
#     input 1: dtype=float32, shape=(312, 20, 200), strides=(4000, 200, 1)
#     input 2: dtype=float32, shape=(312, 20, 200), strides=(4000, 200, 1)
#     input 3: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     input 4: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     input 5: dtype=float32, shape=(313, 20, 200), strides=(4000, 200, 1)
#     input 6: dtype=float32, shape=(313, 20, 200), strides=(4000, 200, 1)
#     input 7: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     input 8: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     input 9: dtype=float32, shape=(37876,), strides=c
#     output 0: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     output 1: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     output 2: dtype=float32, shape=(313, 20, 200), strides=(4000, 200, 1)
#     output 3: dtype=float32, shape=(313, 20, 200), strides=(4000, 200, 1)
#     output 4: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#     output 5: dtype=float32, shape=(313, 20, 50), strides=(1000, 50, 1)
#    0.0%    99.7%       0.106s       3.31e-03s     32   622                     GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0)
#     input 0: dtype=float32, shape=(), strides=c
#     input 1: dtype=int64, shape=(), strides=c
#     input 2: dtype=int64, shape=(), strides=c
#     output 0: dtype=float32, shape=(337, 37876), strides=c
#    0.0%    99.7%       0.101s       3.16e-03s     32   219                     GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0)
#     input 0: dtype=float32, shape=(), strides=c
#     input 1: dtype=int64, shape=(), strides=c
#     input 2: dtype=int64, shape=(), strides=c
#     output 0: dtype=float32, shape=(337, 37876), strides=(37876, 1)
#    0.0%    99.7%       0.070s       2.19e-03s     32   335                     GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0)
#     input 0: dtype=float32, shape=(), strides=c
#     input 1: dtype=int64, shape=(), strides=c
#     input 2: dtype=int64, shape=(), strides=c
#     output 0: dtype=float32, shape=(337, 37876), strides=c
#    0.0%    99.7%       0.054s       1.69e-03s     32   573                     GpuDot22(GpuReshape{2}.0, GpuReshape{2}.0)
#     input 0: dtype=float32, shape=(1680, 23), strides=c
#     input 1: dtype=float32, shape=(23, 200), strides=c
#     output 0: dtype=float32, shape=(1680, 200), strides=c
#    0.0%    99.7%       0.051s       1.59e-03s     32   817                     GpuDot22(GpuReshape{2}.0, GpuDimShuffle{1,0}.0)
#     input 0: dtype=float32, shape=(1680, 200), strides=c
#     input 1: dtype=float32, shape=(200, 23), strides=c
#     output 0: dtype=float32, shape=(1680, 23), strides=c
#    0.0%    99.7%       0.050s       1.25e-02s      4   235                     RandomFunction{normal}(<RandomStateType>, Elemwise{Cast{int32}}.0, TensorConstant{0.0}, TensorConstant{1.0})
#     input 0: dtype=no dtype, shape=None, strides=input no strides
#     input 1: dtype=int32, shape=(2L,), strides=c
#     input 2: dtype=float32, shape=(), strides=c
#     input 3: dtype=float32, shape=(), strides=c
#     output 0: dtype=no dtype, shape=None, strides=input no strides
#     output 1: dtype=float32, shape=(6240L, 16L), strides=c
#    0.0%    99.8%       0.048s       1.50e-03s     32   903                     GpuIncSubtensor{Inc;:int64:}(GpuAlloc{memset_0=True}.0, GpuSubtensor{::int64}.0, ScalarFromTensor.0)
#     input 0: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#     input 1: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 2: dtype=int64, shape=8, strides=c
#     output 0: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#    0.0%    99.8%       0.045s       1.41e-03s     32   899                     GpuIncSubtensor{Inc;:int64:}(GpuAlloc{memset_0=True}.0, GpuSubtensor{::int64}.0, ScalarFromTensor.0)
#     input 0: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#     input 1: dtype=float32, shape=(336, 5, 200), strides=(-1000, 200, 1)
#     input 2: dtype=int64, shape=8, strides=c
#     output 0: dtype=float32, shape=(336, 5, 200), strides=(1000, 200, 1)
#    0.0%    99.8%       0.044s       1.37e-03s     32   576                     GpuDot22(GpuReshape{2}.0, GpuElemwise{sqr,no_inplace}.0)
#     input 0: dtype=float32, shape=(1680, 23), strides=c
#     input 1: dtype=float32, shape=(23, 200), strides=c
#     output 0: dtype=float32, shape=(1680, 200), strides=c
#    0.0%    99.8%       0.038s       1.19e-03s     32   143                     GpuDot22(GpuReshape{2}.0, GpuReshape{2}.0)
#     input 0: dtype=float32, shape=(1680, 7), strides=(7, 1)
#     input 1: dtype=float32, shape=(7, 200), strides=(200, 1)
#     output 0: dtype=float32, shape=(1680, 200), strides=(200, 1)
#    0.0%    99.8%       0.037s       1.16e-03s     32   528                     GpuJoin(TensorConstant{2}, GpuReshape{3}.0, GpuReshape{3}.0)
#     input 0: dtype=int8, shape=(), strides=c
#     input 1: dtype=float32, shape=(336, 5, 16), strides=c
#     input 2: dtype=float32, shape=(336, 5, 16), strides=c
#     output 0: dtype=float32, shape=(336, 5, 32), strides=c
#    ... (remaining 1294 Apply instances account for 0.23%(2.17s) of the runtime)
#
# Memory Profile (the max between all functions in that profile)
# (Sparse variables are ignored)
# (For values in brackets, it's for linker = c|py
# ---
#     Max if no gc (allow_gc=False): 210417KB (210417KB)
#     CPU: 403KB (403KB)
#     GPU: 210295KB (210295KB)
# ---
#     Max if linker=cvm(default): 173523KB (192067KB)
#     CPU: 390KB (390KB)
#     GPU: 173416KB (191961KB)
# ---
#     Memory saved if views are used: 67785KB (67785KB)
#     Memory saved if inplace ops are used: 194270KB (194270KB)
#     Memory saved if gc is enabled: 36893KB (18350KB)
# ---
#
#     This list is based on all functions in the profile
#     <Sum apply outputs (bytes)> <Apply outputs shape> <created/inplace/view> <Apply node>
#
#       57788848B  [(337, 5, 50), (337, 5, 50), (337, 5, 200), (337, 5, 200), (337, 5, 50), (337, 5, 50), (337, 37876), (336, 5, 200), (336, 5, 200)] i i i i i i i c c forall_inplace,gpu,grad_of_scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuSubtensor{::int64}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, Elemwise{minimum,no_inplace}.0, Elemwise{minimum,no_inplace}.0, parameters)
#       57788848B  [(337, 5, 50), (337, 5, 50), (337, 5, 200), (337, 5, 200), (337, 5, 50), (337, 5, 50), (337, 37876), (336, 5, 200), (336, 5, 200)] i i i i i i i c c forall_inplace,gpu,grad_of_scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuSubtensor{::int64}.0, GpuSubtensor{::int64}.0, GpuAlloc{memset_0=True}.0, Elemwise{minimum,no_inplace}.0, Elemwise{minimum,no_inplace}.0, parameters)
#       57788848B  [(337, 5, 50), (337, 5, 50), (337, 5, 200), (337, 5, 200), (337, 5, 50), (337, 5, 50), (337, 37876), (336, 5, 200), (336, 5, 200)] i i i i i i i c c forall_inplace,gpu,grad_of_scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuSubtensor{::int64}.0, GpuSubtensor{::int64}.0, GpuAlloc{memset_0=True}.0, Elemwise{minimum,no_inplace}.0, Elemwise{minimum,no_inplace}.0, parameters)
#       51056848B  [(337, 37876)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0)
#       51056848B  [(337, 37876)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0)
#       51056848B  [(337, 37876)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{0}.0)
#       15024000B  [(313, 20, 50), (313, 20, 50), (313, 20, 200), (313, 20, 200), (313, 20, 50), (313, 20, 50)] i i i i i i forall_inplace,gpu,scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int64}.0, GpuSubtensor{int64:int64:int64}.0, GpuAlloc{memset_0=True}.0, GpuIncSubtensor{Set;:int64:}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuIncSubtensor{Set;:int64:}.0, GpuIncSubtensor{InplaceSet;:int64:}.0, parameters)
#       15024000B  [(313, 20, 50), (313, 20, 50), (313, 20, 200), (313, 20, 200), (313, 20, 50), (313, 20, 50)] i i i i i i forall_inplace,gpu,scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int8}.0, GpuSubtensor{int64:int64:int8}.0, GpuAlloc{memset_0=True}.0, GpuIncSubtensor{Set;:int64:}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuIncSubtensor{Set;:int64:}.0, GpuIncSubtensor{InplaceSet;:int64:}.0, parameters)
#       15024000B  [(313, 20, 50), (313, 20, 50), (313, 20, 200), (313, 20, 200), (313, 20, 50), (313, 20, 50)] i i i i i i forall_inplace,gpu,scan_fn}(Elemwise{minimum,no_inplace}.0, GpuSubtensor{int64:int64:int8}.0, GpuSubtensor{int64:int64:int8}.0, GpuAlloc{memset_0=True}.0, GpuIncSubtensor{Set;:int64:}.0, GpuAlloc{memset_0=True}.0, DeepCopyOp.0, GpuIncSubtensor{Set;:int64:}.0, GpuIncSubtensor{InplaceSet;:int64:}.0, parameters)
#        5008000B  [(313, 20, 200)] c DeepCopyOp(GpuAlloc{memset_0=True}.0)
#        5008000B  [(313, 20, 200)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{1}.0, TensorConstant{200})
#        5008000B  [(313, 20, 200)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{1}.0, TensorConstant{200})
#        5008000B  [(313, 20, 200)] c DeepCopyOp(GpuAlloc{memset_0=True}.0)
#        5008000B  [(313, 20, 200)] c DeepCopyOp(GpuAlloc{memset_0=True}.0)
#        5008000B  [(313, 20, 200)] c GpuAlloc{memset_0=True}(CudaNdarrayConstant{0.0}, Elemwise{add,no_inplace}.0, Shape_i{1}.0, TensorConstant{200})
#        4992000B  [(6240, 200)] i GpuElemwise{Add}[(0, 0)](GpuDot22.0, GpuDimShuffle{x,0}.0)
#        4992000B  [(6240, 200)] c GpuDot22(GpuReshape{2}.0, GpuElemwise{sqr,no_inplace}.0)
#        4992000B  [(312, 20, 200)] v GpuReshape{3}(GpuDot22.0, MakeVector.0)
#        4992000B  [(312, 20, 200)] v GpuSubtensor{int64:int64:int8}(GpuReshape{3}.0, ScalarFromTensor.0, ScalarFromTensor.0, Constant{1})
#        4992000B  [(312, 20, 200)] v GpuReshape{3}(GpuElemwise{Add}[(0, 0)].0, MakeVector.0)
#    ... (remaining 1294 Apply account for 260698862B/687315950B ((37.93%)) of the Apply with dense outputs sizes)
#
#     <created/inplace/view> is taken from the Op's declaration.
#     Apply nodes marked 'inplace' or 'view' may actually allocate memory, this is not reported here. If you use DebugMode, warnings will be emitted in those cases.

# %%
# Recover best parameters.
m.parameters.data[...] = info['best_pars']
# Out:
# 151504 752640 174720
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-efac96e6f9d3> in <module>()
#       3 print m.parameters.data.size * 4, X.size*4, VX.size*4
#       4 for _, value in infos[0].iteritems():
# ----> 5     print value.size
#       6 sum([i.size for i in infos[0]])
#
# AttributeError: 'int' object has no attribute 'size'

# %% [markdown]
# ## Find optimal visible noise
#
# We perform an exhaustive search over 20 candidates for the best noise
# variance. Yes, this could be done more intelligently.

# %%
f_loss = m.function(['inpt', 'imp_weight'], 'loss')

# %%
def f(x):
    x = np.array(x).astype('float32')
    assumptions.out_std.set_value(x)
    return m.estimate_nll(VX)

# %%
cands = np.linspace(1e-8, 2, 20)
bounds = [f(i) for i in cands]
best, cand = min(zip(bounds, cands))
print cand
# Out:
# 0.105263167368

# %%
print cand
# Out:
# 0.105263167368

# %%
assumptions.out_std.set_value(np.array(cand).astype('float32'))

# %% [markdown]
# Evaluation
# ---
#
# The values for the training/validation do *not* respect the importance weights.

# %%
print 'Bound %.2f    NLL estimate %g for training' % (f_loss(X, M), m.estimate_nll(X, 5))
print 'Bound %.2f    NLL estimate %g for validation' % (f_loss(VX, VM), m.estimate_nll(VX, 5))
print 'Bound %.2f    NLL estimate %g for testing' % (f_loss(txs, np.ones_like(txs)), m.estimate_nll(tx[0][:, np.newaxis], 5))
# Out:
# Bound -1.18    NLL estimate -1.1856 for training
# Bound -1.25    NLL estimate -1.17237 for validation
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-505734893745> in <module>()
#       1 print 'Bound %.2f    NLL estimate %g for training' % (f_loss(X, np.ones_like(M)), m.estimate_nll(X, 5))
#       2 print 'Bound %.2f    NLL estimate %g for validation' % (f_loss(VX, VM), m.estimate_nll(VX, 5))
# ----> 3 print 'Bound %.2f    NLL estimate %g for testing' % (f_loss(txs, np.ones_like(txs)), m.estimate_nll(tx[0][:, np.newaxis], 5))
#
# z:\anomalydetection\breze\breze\arch\util.pyc in f_implicit_pars(*args, **kwargs)
#     576         if not explicit_pars:
#     577             def f_implicit_pars(*args, **kwargs):
# --> 578                 return f(self.parameters.data, *args, **kwargs)
#     579             f_implicit_pars.theano_func = f
#     580             f_implicit_pars.breze_func = True
#
# \\srv-file.brml.tum.de\nthome\msoelch\AppData\Roaming\Python\Python27\site-packages\theano\compile\function_module.pyc in __call__(self, *args, **kwargs)
#     513                     try:
#     514                         s.storage[0] = s.type.filter(arg, strict=s.strict,
# --> 515                                 allow_downcast=s.allow_downcast)
#     516
#     517                     except Exception, e:
#
# \\srv-file.brml.tum.de\nthome\msoelch\AppData\Roaming\Python\Python27\site-packages\theano\tensor\type.pyc in filter(self, data, strict, allow_downcast)
#     139                     # data has to be converted.
#     140                     # Check that this conversion is lossless
# --> 141                     converted_data = theano._asarray(data, self.dtype)
#     142                     # We use the `values_eq` static function from TensorType
#     143                     # to handle NaN values.
#
# \\srv-file.brml.tum.de\nthome\msoelch\AppData\Roaming\Python\Python27\site-packages\theano\misc\safe_asarray.pyc in _asarray(a, dtype, order)
#      31         dtype = theano.config.floatX
#      32     dtype = numpy.dtype(dtype)  # Convert into dtype object.
# ---> 33     rval = numpy.asarray(a, dtype=dtype, order=order)
#      34     # Note that dtype comparison must be done by comparing their `num`
#      35     # attribute. One cannot assume that two identical data types are pointers
#
# C:\Anaconda\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     458
#     459     """
# --> 460     return array(a, dtype, copy=False, order=order)
#     461
#     462 def asanyarray(a, dtype=None, order=None):
#
# ValueError: ('Bad input argument to theano function with name "z:\\anomalydetection\\breze\\breze\\arch\\util.py:571"  at index 1(0-based)', 'setting an array element with a sequence.')

# %% [markdown]
# ## Learning curves

# %%
start = 0
plt.plot([(i['loss']) for i in infos[start:]])
plt.plot([i['val_loss'] for i in infos[start:]])
#plt.plot([i['max_grad'] / 200. for i in infos[200:]])

# %% [markdown]
# ## Sampling

# %%
prefix_length = 50
sample_length = 70
x = np.concatenate([VX[:, :1]] * 50, axis=1)
S = m.sample(sample_length, x[:prefix_length], visible_map=True)

# %%
angle_idxs = range(7)
sample_idx = 0
xs = np.arange(prefix_length + sample_length - 1)

fig, axs = plt.subplots(3, 3, figsize=(16, 9))

axs = list(itertools.chain(*axs))
for i, ax in zip(angle_idxs, axs):
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)
    
    _ = ax.plot(xs[prefix_length:], S[:, :, i], 'k', alpha=.2)
    _ = ax.axhline(0)
    _ = ax.plot(VX[:, 0, i], label='stimulus')

axs[-1].plot([0, 0], [0, 0], 'k', label='sample')
axs[-1].set_ylim([-100, -99])
axs[-1].set_xlim([-100, -99])
axs[-1].legend(loc=0)

#axs[1][0].set_title('original data')
#axs[1][1].set_title('denoised data')

#plt.savefig('/Users/bayerj/Desktop/stimulus-sampling.pdf', bbox_inches='tight')

# %%
angle_idxs = range(7)
sample_idx = 0
xs = np.arange(prefix_length + sample_length - 1)

fig, axs = plt.subplots(1, 1, figsize=(16, 9), squeeze=False)

axs = list(itertools.chain(*axs))

j,k = 0,1
for i, ax in zip(angle_idxs, axs):
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)
    
    _ = ax.plot(S[:, :, j], S[:, :, k], 'k', alpha=.2)

    _ = ax.plot(VX[:, :, j], VX[:, :, k], label='stimulus')


#axs[1][0].set_title('original data')
#axs[1][1].set_title('denoised data')

#plt.savefig('/Users/bayerj/Desktop/stimulus-sampling.pdf', bbox_inches='tight')

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Probabilistic

# %%
rng = T.shared_randomstreams.RandomStreams()
predict_expr_noisy = theano.clone(m.vae.output, 
                            {m.vae.sample: rng.normal(m.vae.sample.shape)})
f_predict_noisy = m.function(['inpt'], predict_expr_noisy)

# %%
x = tx[0][:, np.newaxis]
ys = [f_predict_noisy(x)[:, :1, :49] for i in range(10)]
y = np.mean(ys, axis=0)

# %%
print 'approx prob prediction', ((y - x) ** 2).mean(0).sum()
# Out:
# approx prob prediction 6.54298978013

# %% [markdown]
# ### Latent Mode

# %%
f_predict = m.function(['inpt'], 'output', givens={m.vae.sample: T.zeros_like(m.vae.sample)})

# %%
x = tx[0][:, np.newaxis]
y = f_predict(x)[:, :1, :49]

# %%
print 'map prediction', ((y - x) ** 2).mean(0).sum()
# Out:
# map prediction 6.52376176776

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 16))

axs = list(itertools.chain(*axs))[:49]
for i, ax in enumerate(axs):
    ax.plot(x[:, 0, [i]], label='true', linewidth=1)
    ax.plot(y[:, 0, [i]], label='predicted', linewidth=1)
    ax.plot(abs(x - y)[:, 0, [i]] - 5, 'k.', label='|residual|')
    ax.set_ylim([-5, 3])
    #ax.set_title('dimension %i' % i)
    ax.set_yticks([])
    ax.set_xticks([])

axs[0].legend()

# %% [markdown]
# Reconstruction
# ---

# %%
f_reconstruct = m.function(['inpt'], 'output')

# %%
R = f_reconstruct(X)[:, :, :7]

# %%
fig, axs = plt.subplots(3, 3, figsize=(16, 16))
start, stop = 0, -1

axs = list(itertools.chain(*axs))[:7]
for i, ax in enumerate(axs):
    ax.plot(X[start:stop, 0, [i]], label='truth', linewidth=1)
    ax.plot(R[start:stop, 0, [i]], label='reconstruction', linewidth=1)
    #ax.plot(noisy[start:stop, 0, [i]], label='noisy', linewidth=1)
    #ax.plot(denoised[start:stop, 0, [i]], label='denoised', linewidth=2, color='k')
    #ax.plot(abs(noisy[:, :, :49] - X)[:, 0, [i]] - 5, 'r.', label='|residual noisy|')
    #ax.plot(abs(denoised[:, :, :49] - X)[:, 0, [i]] - 5, 'b.', label='|residual denoised|')
    ax.set_ylim([-5, 3])
    #ax.set_title('dimension %i' % i)
    ax.set_yticks([])
    ax.set_xticks([])

axs[0].legend()

# %% [markdown]
# Missing Value Imputation
# ---

# %%
sample_map = m.vae.latent[:, :, :n_latents]
gen_inpt = T.concatenate([sample_map, m.vae.condition], axis=2)

map_recons_exprs = theano.clone(m.exprs['output'], 
                                {m.vae.sample: sample_map})
f_map_recons = m.function(['inpt'], map_recons_exprs)

# %%
def map_impute(start, to_impute_idxs, n_steps=10):
    denoised = start.copy()
    denoised[to_impute_idxs] = np.random.standard_normal(denoised[to_impute_idxs].shape)
    noisy = denoised.copy()
    
    for i in range(n_steps):
        reconstructed = f_map_recons(denoised)
        denoised[to_impute_idxs] = reconstructed[:, :, :49][to_impute_idxs]
    return noisy, denoised

# %%
clean = VX[:, :1]
mask = np.zeros_like(clean).astype('uint8')
mask[30:40][...] = 1
to_impute_idxs = np.where(mask)
#noised[to_impute_idxs] = np.random.standard_normal(noised[to_impute_idxs].shape) * 1

noisy, denoised = map_impute(clean, to_impute_idxs, 100)

# %%
angle_idxs = range(49)
sample = 0

fig, axs = plt.subplots(7, 7, figsize=(16, 9))

xs = np.arange(X.shape[0])
axs = list(itertools.chain(*axs))
for i, ax in zip(angle_idxs, axs):
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)

    _ = ax.plot(xs[to_impute_idxs[0]], noisy[to_impute_idxs[0], 0, i], 'r-', linewidth=1, label='noisy', alpha=.3)
    _ = ax.plot(xs[to_impute_idxs[0]], denoised[to_impute_idxs[0], 0, i], 'k-', linewidth=1, label='imputed')
    _ = ax.plot(xs, clean[:, 0, i], 'b-', linewidth=1, label='truth', alpha=.5)

axs[-1].set_ylim([-100, -99])
axs[-1].set_xlim([-100, -99])
axs[-1].legend(loc=0)

#axs[1][0].set_title('original data')
#axs[1][1].set_title('denoised data')

plt.savefig('/Users/bayerj/Desktop/imputed.pdf', bbox_inches='tight')

# %% [markdown]
# Latent trajectories
# ---

# %%
f_latent = m.function(['inpt'], m.vae.latent)

# %%
L = f_latent(VX[:, :10])
Lm, Ls = L[:, :, :m.n_latent], L[:, :, m.n_latent:]

# %%
fig, axs = plt.subplots(5, 5, figsize=(16, 16))

def plot_latent_trajectory(ax, mean, vr):
        ax.plot(mean, 'k+-')
        #ax.plot(mean + std, 'k--')
        #ax.plot(mean - std, 'k--')
        
        x = np.arange(mean.shape[0])
        ax.fill(
            np.concatenate([x, x[::-1]]),
            np.concatenate([mean - vr, (mean + vr)[::-1]]),
            alpha=.5, fc='b', ec='None')
        ax.set_xticks([])
        ax.set_yticks([-1, 0, 1])

axs_flat = itertools.chain(*axs)

#active = [6, 7, 9, 20, 26, 32, 37, 60]
active = range(64)

for i, ax in enumerate(axs_flat):
    try:
        plot_latent_trajectory(ax, Lm[:, 0, i], Ls[:, 0, i])
    except IndexError:
        break

# %%
f_bound = m.function(['inpt', 'imp_weight'], m.loss_sample_wise)

tls = [f_bound(i[:,np.newaxis], np.ones_like(i[:,np.newaxis,:1])) for i in txs]

# %%
tls[0].shape
# Out:
# (299L, 1L)

# %%
fig, axs = plt.subplots(1, 1, figsize=(16, 9), squeeze=False)
for i, j in zip(tls,tzs):
    axs[0][0].plot(i,"k-" if j else "r-")

# %%
tlmax = [np.median(list(sorted(i)[-5:])) for i in tls]
print len(tlmax)
# Out:
# 40

# %%
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(tzs, tlmax)
print metrics.roc_auc_score(tzs, tlmax)
print metrics.f1_score(tzs, tlmax, )
fig, ax = plt.subplots(1, 1, figsize=(9, 9))
ax.plot(fpr, tpr, linewidth=2)
ax.set_ylabel('true positive rate')
ax.set_xlabel('false positive rate')
ax.set_xlim(0, 1.0)
# Out:
# 0.7775
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-71806bfde61c> in <module>()
#       2 fpr, tpr, thresholds = metrics.roc_curve(tzs, tlmax)
#       3 print metrics.roc_auc_score(tzs, tlmax)
# ----> 4 print metrics.f1_score(tzs, tlmax)
#       5 fig, ax = plt.subplots(1, 1, figsize=(9, 9))
#       6 ax.plot(fpr, tpr, linewidth=2)
#
# C:\Anaconda\lib\site-packages\sklearn\metrics\metrics.py in f1_score(y_true, y_pred, labels, pos_label, average)
#    1155     """
#    1156     return fbeta_score(y_true, y_pred, 1, labels=labels,
# -> 1157                        pos_label=pos_label, average=average)
#    1158
#    1159
#
# C:\Anaconda\lib\site-packages\sklearn\metrics\metrics.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average)
#    1247                                                  labels=labels,
#    1248                                                  pos_label=pos_label,
# -> 1249                                                  average=average)
#    1250     return f
#    1251
#
# C:\Anaconda\lib\site-packages\sklearn\metrics\metrics.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average)
#    1466     beta2 = beta ** 2
#    1467
# -> 1468     y_type, y_true, y_pred = _check_clf_targets(y_true, y_pred)
#    1469
#    1470     if labels is None:
#
# C:\Anaconda\lib\site-packages\sklearn\metrics\metrics.py in _check_clf_targets(y_true, y_pred)
#     113     if len(y_type) > 1:
#     114         raise ValueError("Can't handle mix of {0} and {1}"
# --> 115                          "".format(type_true, type_pred))
#     116
#     117     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Can't handle mix of binary and continuous
